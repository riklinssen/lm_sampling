# %%
import googlemaps
from dotenv import load_dotenv
import os
import ast
import numpy as np
from geopy.distance import geodesic
import pandas as pd
import geopandas as gpd
import time
from pathlib import Path
from geopy.geocoders import Nominatim
import re

# %%
PROJECT_ROOT = Path().absolute().parent
DATA_DIR = PROJECT_ROOT / 'data'
RAW_DATA_DIR = DATA_DIR / 'raw'
PROCESSED_DATA_DIR = DATA_DIR / 'processed'
TEMP_DATA_DIR = DATA_DIR / 'temp'

#load in data 
sampled_clusters_gdf=gpd.read_file(PROCESSED_DATA_DIR/'sampled_clusters.gpkg')
print(sampled_clusters_gdf.station_name.value_counts(dropna=False))
#there are non-unique grid ids. 
print(sampled_clusters_gdf.grid_id.is_unique)

sampled_clusters_gdf
# Out:
# station_name
# Aisa FM        70
# Dwanwana FM    70
# Dokolo FM      70
# Name: count, dtype: int64
# True
#      grid_id station_name  population_count  household_count  buffer_km  \
# 0      21965      Aisa FM        412.028381        84.087425       25.0
# 1      22136      Aisa FM        867.115967       176.962442       25.0
# 2      21627      Aisa FM       1342.766846       274.034050       25.0
# 3      20438      Aisa FM       1109.628174       226.454729       25.0
# 4      21119      Aisa FM        802.255127       163.725536       25.0
# ..       ...          ...               ...              ...        ...
# 205     9481    Dokolo FM        488.350555        99.663379       25.0
# 206     9312    Dokolo FM        304.447693        62.132182       25.0
# 207    11348    Dokolo FM        424.834106        86.700838       25.0
# 208    11690    Dokolo FM        219.438843        44.783437       25.0
# 209    12878    Dokolo FM        479.428192        97.842488       25.0
#
#     cluster_type  psu_prob                                    psu_explanation  \
# 0           main  0.045243  1km by 1km grid cells in 25 km radio station r...
# 1           main  0.095213  1km by 1km grid cells in 25 km radio station r...
# 2    replacement  0.147442  1km by 1km grid cells in 25 km radio station r...
# 3           main  0.121842  1km by 1km grid cells in 25 km radio station r...
# 4    replacement  0.088091  1km by 1km grid cells in 25 km radio station r...
# ..           ...       ...                                                ...
# 205  replacement  0.074282  1km by 1km grid cells in 25 km radio station r...
# 206  replacement  0.046309  1km by 1km grid cells in 25 km radio station r...
# 207  replacement  0.064621  1km by 1km grid cells in 25 km radio station r...
# 208         main  0.033378  1km by 1km grid cells in 25 km radio station r...
# 209  replacement  0.072925  1km by 1km grid cells in 25 km radio station r...
#
#      ssu_prob                                    ssu_explanation  \
# 0    0.142709  second stage unit=households, inclusion probab...
# 1    0.067811  second stage unit=households, inclusion probab...
# 2    0.043790  second stage unit=households, inclusion probab...
# 3    0.052991  second stage unit=households, inclusion probab...
# 4    0.073293  second stage unit=households, inclusion probab...
# ..        ...                                                ...
# 205  0.120405  second stage unit=households, inclusion probab...
# 206  0.193137  second stage unit=households, inclusion probab...
# 207  0.138407  second stage unit=households, inclusion probab...
# 208  0.267956  second stage unit=households, inclusion probab...
# 209  0.122646  second stage unit=households, inclusion probab...
#
#      centroid_lon  centroid_lat  \
# 0       33.784595      1.242797
# 1       33.793586      1.251841
# 2       33.766624      1.260896
# 3       33.703710      1.269960
# 4       33.739665      1.278996
# ..            ...           ...
# 205     33.119498      2.111445
# 206     33.110505      2.120492
# 207     33.218414      2.084292
# 208     33.236402      2.102384
# 209     33.299347      2.084279
#
#                                               geometry
# 0    POLYGON ((33.78909 1.23827, 33.78909 1.24732, ...
# 1    POLYGON ((33.79808 1.24732, 33.79808 1.25636, ...
# 2    POLYGON ((33.77112 1.25637, 33.77112 1.26542, ...
# 3    POLYGON ((33.7082 1.26544, 33.7082 1.27448, 33...
# 4    POLYGON ((33.74416 1.27447, 33.74416 1.28352, ...
# ..                                                 ...
# 205  POLYGON ((33.12399 2.10692, 33.12399 2.11597, ...
# 206  POLYGON ((33.115 2.11597, 33.115 2.12502, 33.1...
# 207  POLYGON ((33.22291 2.07977, 33.22291 2.08882, ...
# 208  POLYGON ((33.2409 2.09786, 33.2409 2.10691, 33...
# 209  POLYGON ((33.30384 2.07975, 33.30384 2.0888, 3...
#
# [210 rows x 13 columns]

# %%
#split this up in batches, dwanwana dokolo first then aisa fm. 

dwanwana_dokolo_sampled_clusters_gdf=sampled_clusters_gdf.loc[sampled_clusters_gdf['station_name'].isin(['Dwanwana FM', 'Dokolo FM'])]
aisa_sampled_clusters_gdf=sampled_clusters_gdf.loc[sampled_clusters_gdf['station_name']=='Aisa FM']
#['Aisa FM', 'Dwanwana FM', 'Dokolo FM']
# Load API key
load_dotenv()
api_key = os.getenv('GOOGLE_MAPS_API_KEY')
gmaps = googlemaps.Client(key=api_key)

def get_points_on_circle(center_lat, center_lon, radius_meters, num_points=4):
    """Generate points on a circle around the center point."""
    radius_deg = radius_meters / 111000 #convert degrees to meters (1 degree ~ 111000 meters)
    
    points = []
    for i in range(num_points):
        angle = 2 * np.pi * i / num_points # create evenly spaced points, calculate the angle where to place te point, circle is 2 pi radians (360 degrees), divide by number of points to evenly space out. 
        lat = center_lat + radius_deg * np.cos(angle) #cosine gives north south position (constant across globe-->latitude)
        lon = center_lon + radius_deg * np.sin(angle) / np.cos(np.radians(center_lat)) # longitude east west component, adjust for curvature by --> dividing by cosine latitude as east west 'shrinks'  at higher latitudes (and we'd otherwise draw an oval)
        points.append((lat, lon))
    
    return points

def find_nearest_road(center_lat, center_lon, gmaps_client, verbose=False):
    """
    Find the nearest road point to a given centroid.
    Stops searching as soon as a road is found in the first radius.
    """
    try:
        # Define search radii
        search_radii = [25, 50, 100, 150, 200] #define search radii, draw a circle around the centroid. 
        
        if verbose:
            print(f"\nOriginal centroid (lat, lon): {center_lat}, {center_lon}") 
        
        closest_point = None
        min_distance = float('inf')
        
        # Search at increasing radii
        for radius in search_radii:
            if verbose:
                print(f"\nSearching at {radius} meters radius...")
            
            num_points = 4 if radius <= 50 else 8 #get 8 points on the circle
            test_points = get_points_on_circle(center_lat, center_lon, radius_meters=radius, num_points=num_points) 
            
            road_found = False  # Flag for finding any road, start at fale. 
            
            for i, origin in enumerate(test_points):
                if verbose:
                    print(f"Trying direction search {i+1}/{num_points} at {radius}m radius")
                
                destination = (center_lat, center_lon)
                
                # Get directions response object from the API. 
                directions_result = gmaps_client.directions(
                    origin=origin,
                    destination=destination,
                    mode="driving"
                )
                print(directions_result)
                if directions_result:
                    steps = directions_result[0]['legs'][0]['steps'] #api gives directions in results and steps as json object/dictionary
                    ##[{'bounds': {'northeast': {'lat': 2.120286, 'lng': 33.2175956}, 'southwest': {'lat': 2.120286, 'lng': 33.2175956}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 2.120286, 'lng': 33.2175956}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 2.120286, 'lng': 33.2175956}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 2.120286, 'lng': 33.2175956}, 'html_instructions': 'Head', 'polyline': {'points': 'yb}K_yviE'}, 'start_location': {'lat': 2.120286, 'lng': 33.2175956}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'yb}K_yviE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]

                    last_step = steps[-1] #take the last step capture the last point before moving off the road. 
                    
                    road_lat = last_step['start_location']['lat'] #capture the coordinates of the point where the directions leave the road (last step), latitude
                    road_lon = last_step['start_location']['lng'] #and longitude
                    #calculate the distance between 2 points using geodesic, to establish what the closest 'leave the road point'  is to the centroid. 
                    distance = geodesic(
                        (center_lat, center_lon), 
                        (road_lat, road_lon)
                    ).meters
                    
                    if verbose:
                        print(f"Found road point at distance: {distance:.1f}m")
                    
                    road_found = True
                    
                    if distance < min_distance: #get the minumum distance if so, get the road lat and lon. 
                        min_distance = distance
                        closest_point = {
                            'lat': road_lat,
                            'lon': road_lon,
                            'distance': distance,
                            'found_at_radius': radius
                        }
            
            # If we found any road in this radius, stop searching
            if road_found and radius == 25:  # Only stop if we found a road in the first radius
                if verbose:
                    print(f"\nFound road within first radius ({radius}m), stopping search")
                break
        
        return closest_point
                
    except Exception as e:
        if verbose:
            print(f"Error: {e}")
        return None

# %%
def process_all_clusters(sampled_clusters_gdf):
    """
    Process all clusters to find nearest roads for their centroids.
    Returns a DataFrame with results.
    """
    # Initialize results list
    results = []
    
    # Total number of clusters for progress tracking
    total_clusters = len(sampled_clusters_gdf)
    print(f"Starting to process {total_clusters} clusters...")
    
    for idx, row in sampled_clusters_gdf.iterrows():
        print(f"\nProcessing {idx+1}/{total_clusters}: grid_id {row.grid_id}")
        
        try:
            # Get centroid coordinates
            center_lat, center_lon = row.centroid_lat, row.centroid_lon
            
            # Find nearest road
            closest_point = find_nearest_road(center_lat, center_lon, gmaps, verbose=True)
            
            # Store results
            result = {
                'grid_id': row.grid_id,
                'station_name': row.station_name,
                'buffer_km':row.buffer_km,
                'est_population_2020':row.population_count,
                'centroid_lat': center_lat,
                'centroid_lon': center_lon,
                'centroid_maps_link': f"https://www.google.com/maps?q={center_lat},{center_lon}",
                'cluster_type': row.cluster_type,
                'nearest_road_lat': closest_point['lat'] if closest_point else None,
                'nearest_road_lon': closest_point['lon'] if closest_point else None,
                'distance_to_road': closest_point['distance'] if closest_point else None,
                'nearest_road_maps_link': (f"https://www.google.com/maps?q={closest_point['lat']},{closest_point['lon']}" 
                                         if closest_point else None),
                'found_at_radius': closest_point['found_at_radius'] if closest_point else None,
                'processing_success': True if closest_point else False,
                'geometry_grid_cell': row.geometry.wkt  
            }
            
            results.append(result)
            
            # small delay to avoid hitting API limits/overflooding API.
            time.sleep(0.1)
            
        except Exception as e:
            print(f"Error processing grid_id {row.grid_id}: {e}") #check for weird stuff happening. 
            # store error result
            result = {
                'grid_id': row.grid_id,
                'station_name': row.station_name,
                'buffer_km':row.buffer_km,
                'est_population_2020':row.population_count,
                'centroid_lat': center_lat,
                'centroid_lon': center_lon,
                'centroid_maps_link': f"https://www.google.com/maps?q={center_lat},{center_lon}",
                'cluster_type': row.cluster_type,
                'nearest_road_lat': None,
                'nearest_road_lon': None,
                'distance_to_road': None,
                'nearest_road_maps_link': None,
                'found_at_radius': None,
                'processing_success': False,
                'geometry_grid_cell': row.geometry.wkt  
            }
            results.append(result)
    
    # Convert results to DataFrame and return
    return pd.DataFrame(results)

# API calls dwanwana_dokolo:
results_dwanwana_dokolo = process_all_clusters(dwanwana_dokolo_sampled_clusters_gdf)

# 560 requests for largest set <5 dollars in credit.
# Out:
# Starting to process 140 clusters...
#
# Processing 71/140: grid_id 9945
#
# Original centroid (lat, lon): 1.6952717679950127, 33.146440813501684
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.6952692, 'lng': 33.146213}, 'southwest': {'lat': 1.6951201, 'lng': 33.1461323}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '19 m', 'value': 19}, 'duration': {'text': '1 min', 'value': 5}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.6951201, 'lng': 33.146213}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.6952692, 'lng': 33.1461323}, 'steps': [{'distance': {'text': '19 m', 'value': 19}, 'duration': {'text': '1 min', 'value': 5}, 'end_location': {'lat': 1.6951201, 'lng': 33.146213}, 'html_instructions': 'Head <b>southeast</b>', 'polyline': {'points': 'mbjIizhiEFEPGBA'}, 'start_location': {'lat': 1.6952692, 'lng': 33.1461323}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'mbjIizhiE\\O'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 34.3m
# Trying direction search 2/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.6951201, 'lng': 33.1462888}, 'southwest': {'lat': 1.695009, 'lng': 33.146213}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '15 m', 'value': 15}, 'duration': {'text': '1 min', 'value': 4}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.6951201, 'lng': 33.146213}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.695009, 'lng': 33.1462888}, 'steps': [{'distance': {'text': '15 m', 'value': 15}, 'duration': {'text': '1 min', 'value': 4}, 'end_location': {'lat': 1.6951201, 'lng': 33.146213}, 'html_instructions': 'Head <b>northwest</b>', 'polyline': {'points': 'y`jIi{hiEIFKF'}, 'start_location': {'lat': 1.695009, 'lng': 33.1462888}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'y`jIi{hiEUN'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 33.6m
# Trying direction search 3/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.6951201, 'lng': 33.1463127}, 'southwest': {'lat': 1.6949746, 'lng': 33.146213}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '20 m', 'value': 20}, 'duration': {'text': '1 min', 'value': 5}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.6951201, 'lng': 33.146213}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.6949746, 'lng': 33.1463127}, 'steps': [{'distance': {'text': '20 m', 'value': 20}, 'duration': {'text': '1 min', 'value': 5}, 'end_location': {'lat': 1.6951201, 'lng': 33.146213}, 'html_instructions': 'Head <b>northwest</b>', 'polyline': {'points': 'q`jIm{hiEQJKF'}, 'start_location': {'lat': 1.6949746, 'lng': 33.1463127}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'q`jIm{hiE]R'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 35.8m
# Trying direction search 4/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.695232, 'lng': 33.146213}, 'southwest': {'lat': 1.6951201, 'lng': 33.1461598}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '14 m', 'value': 14}, 'duration': {'text': '1 min', 'value': 3}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.6951201, 'lng': 33.146213}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.695232, 'lng': 33.1461598}, 'steps': [{'distance': {'text': '14 m', 'value': 14}, 'duration': {'text': '1 min', 'value': 3}, 'end_location': {'lat': 1.6951201, 'lng': 33.146213}, 'html_instructions': 'Head <b>southeast</b>', 'polyline': {'points': 'ebjIozhiEPGBA'}, 'start_location': {'lat': 1.695232, 'lng': 33.1461598}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'ebjIozhiETI'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 31.6m
#
# Found road within first radius (25m), stopping search
#
# Processing 72/140: grid_id 10457
#
# Original centroid (lat, lon): 1.7133639099524243, 33.17341429523779
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.7138673, 'lng': 33.1719391}, 'southwest': {'lat': 1.7138673, 'lng': 33.1719391}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.7138673, 'lng': 33.1719391}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.7138673, 'lng': 33.1719391}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 1.7138673, 'lng': 33.1719391}, 
location': {'lat': 2.0847828, 'lng': 33.2988086}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': '{dvKqtfjE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 81.8m
# Trying direction search 3/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 2.0847828, 'lng': 33.2988086}, 'southwest': {'lat': 2.0847828, 'lng': 33.2988086}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 2.0847828, 'lng': 33.2988086}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 2.0847828, 'lng': 33.2988086}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 2.0847828, 'lng': 33.2988086}, 'html_instructions': 'Head', 'polyline': {'points': '{dvKqtfjE'}, 'start_location': {'lat': 2.0847828, 'lng': 33.2988086}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': '{dvKqtfjE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 81.8m
# Trying direction search 4/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 2.0847828, 'lng': 33.2988086}, 'southwest': {'lat': 2.0847828, 'lng': 33.2988086}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 2.0847828, 'lng': 33.2988086}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 2.0847828, 'lng': 33.2988086}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 2.0847828, 'lng': 33.2988086}, 'html_instructions': 'Head', 'polyline': {'points': '{dvKqtfjE'}, 'start_location': {'lat': 2.0847828, 'lng': 33.2988086}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': '{dvKqtfjE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 81.8m
#
# Found road within first radius (25m), stopping search

# %%
#now for aisa (in batches to check API cost)

# %%
results_aisa = process_all_clusters(aisa_sampled_clusters_gdf)
# Out:
# Starting to process 70 clusters...
#
# Processing 1/70: grid_id 21965
#
# Original centroid (lat, lon): 1.2427973838343365, 33.78459505434681
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'southwest': {'lat': 1.2439385, 'lng': 33.78216340000001}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'html_instructions': 'Head', 'polyline': {'points': 's}qFoaemE'}, 'start_location': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 's}qFoaemE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 298.6m
# Trying direction search 2/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.244969, 'lng': 33.7866427}, 'southwest': {'lat': 1.2448562, 'lng': 33.7865152}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '19 m', 'value': 19}, 'duration': {'text': '1 min', 'value': 2}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.244969, 'lng': 33.7865152}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.2448562, 'lng': 33.7866427}, 'steps': [{'distance': {'text': '19 m', 'value': 19}, 'duration': {'text': '1 min', 'value': 2}, 'end_location': {'lat': 1.244969, 'lng': 33.7865152}, 'html_instructions': 'Head <b>northwest</b>', 'polyline': {'points': 'kcrFo}emEOPED'}, 'start_location': {'lat': 1.2448562, 'lng': 33.7866427}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'kcrFo}emEUV'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 322.1m
# Trying direction search 3/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'southwest': {'lat': 1.2439385, 'lng': 33.78216340000001}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'html_instructions': 'Head', 'polyline': {'points': 's}qFoaemE'}, 'start_location': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 's}qFoaemE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 298.6m
# Trying direction search 4/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'southwest': {'lat': 1.2439385, 'lng': 33.78216340000001}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'html_instructions': 'Head', 'polyline': {'points': 's}qFoaemE'}, 'start_location': {'lat': 1.2439385, 'lng': 33.78216340000001}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 's}qFoaemE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 298.6m
#
# Found road within first radius (25m), stopping search
#
# Processing 2/70: grid_id 22136
#
# Original centroid (lat, lon): 1.2518410784070555, 33.79358575412983
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.2523246, 'lng': 33.7940621}, 'southwest': {'lat': 1.2523246, 'lng': 33.7940621}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.2523246, 'lng': 33.7940621}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.2523246, 'lng': 33.7940621}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 1.2523246, 'lng': 33.7940621}, 'html_instructions': 'Head', 'polyline': {'points': '_rsF{kgmE'}, 'start_location': {'lat': 1.2523246, 'lng': 33.7940621}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': '_rsF{kgmE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 75.3m
# Trying direction search 2/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.2523246, 'lng': 33.7941312}, 'southwest': {'lat': 1.2522734, 'lng': 33.7940621}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '10 m', 'value': 10}, 'duration': {'text': '1 min', 'value': 1}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.2523246, 'lng': 33.7940621}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.2522734, 'lng': 33.7941312}, 'steps': [{'distance': {'text': '10 m', 'value': 10}, 'duration': {'text': '1 min', 'value': 1}, 'end_location': {'lat': 1.2523246, 'lng': 33.7940621}, 'html_instructions': 'Head <b>northwest</b>', 'polyline': {'points': 'uqsFilgmEIL'}, 'start_location': {'lat': 1.2522734, 'lng': 33.7941312}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'uqsFilgmEIL'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 77.3m
# Trying direction search 3/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.2523246, 'lng': 33.7943507}, 'southwest': {'lat': 1.2519537, 'lng': 33.7940621}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '54 m', 'value': 54}, 'duration': {'text': '1 min', 'value': 6}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.2523246, 'lng': 33.7940621}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.2519537, 'lng': 33.7943507}, 'steps': [{'distance': {'text': '54 m', 'value': 54}, 'duration': {'text': '1 min', 'value': 6}, 'end_location': {'lat': 1.2523246, 'lng': 33.7940621}, 'html_instructions': 'Head <b>northwest</b>', 'polyline': {'points': 
'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 102.1m
#
# Found road within first radius (25m), stopping search

# %%
#check results 
print(results_dwanwana_dokolo.head())
print(results_aisa.head(5))
# Out:
#    grid_id station_name  buffer_km  est_population_2020  centroid_lat  \
# 0     9945  Dwanwana FM       25.0           285.974884      1.695272
# 1    10457  Dwanwana FM       25.0           206.037659      1.713364
# 2    11988  Dwanwana FM       25.0           293.460968      1.722402
# 3    11139  Dwanwana FM       25.0           140.694595      1.731455
# 4    11991  Dwanwana FM       25.0           174.438141      1.749543
#
#    centroid_lon                                 centroid_maps_link  \
# 0     33.146441  https://www.google.com/maps?q=1.69527176799501...
# 1     33.173414  https://www.google.com/maps?q=1.71336390995242...
# 2     33.254332  https://www.google.com/maps?q=1.72240196467175...
# 3     33.209379  https://www.google.com/maps?q=1.73145463704553...
# 4     33.254335  https://www.google.com/maps?q=1.74954338634917...
#
#   cluster_type  nearest_road_lat  nearest_road_lon  distance_to_road  \
# 0         main          1.695232         33.146160         31.576369
# 1         main          1.713867         33.171939        173.326007
# 2         main          1.722532         33.252856        164.824625
# 3         main          1.731984         33.208794         87.582263
# 4  replacement          1.748732         33.253528        126.990021
#
#                               nearest_road_maps_link  found_at_radius  \
# 0  https://www.google.com/maps?q=1.695232,33.1461598               25
# 1  https://www.google.com/maps?q=1.7138673,33.171...               25
# 2  https://www.google.com/maps?q=1.7225318,33.252...               25
# 3  https://www.google.com/maps?q=1.7319842,33.208...               25
# 4  https://www.google.com/maps?q=1.7487317,33.253...               25
#
#    processing_success                                 geometry_grid_cell
# 0                True  POLYGON ((33.15093578502719 1.6907478349369018...
# 1                True  POLYGON ((33.1779092357419 1.7088399165561794,...
# 2                True  POLYGON ((33.25882632450752 1.717877801982593,...
# 3                True  POLYGON ((33.21387391257566 1.7269305641425, 3...
# 4                True  POLYGON ((33.258830006044015 1.745019215444507...
#    grid_id station_name  buffer_km  est_population_2020  centroid_lat  \
# 0    21965      Aisa FM       25.0           412.028381      1.242797
# 1    22136      Aisa FM       25.0           867.115967      1.251841
# 2    21627      Aisa FM       25.0          1342.766846      1.260896
# 3    20438      Aisa FM       25.0          1109.628174      1.269960
# 4    21119      Aisa FM       25.0           802.255127      1.278996
#
#    centroid_lon                                 centroid_maps_link  \
# 0     33.784595  https://www.google.com/maps?q=1.24279738383433...
# 1     33.793586  https://www.google.com/maps?q=1.25184107840705...
# 2     33.766624  https://www.google.com/maps?q=1.26089560634678...
# 3     33.703710  https://www.google.com/maps?q=1.26996006966729...
# 4     33.739665  https://www.google.com/maps?q=1.27899647711486...
#
#   cluster_type  nearest_road_lat  nearest_road_lon  distance_to_road  \
# 0         main          1.243939         33.782163        298.596971
# 1         main          1.252325         33.794062         75.292918
# 2  replacement          1.259437         33.766239        166.946571
# 3         main          1.270047         33.703725          9.727099
# 4  replacement          1.277351         33.738072        254.018529
#
#                               nearest_road_maps_link  found_at_radius  \
# 0  https://www.google.com/maps?q=1.2439385,33.782...               25
# 1  https://www.google.com/maps?q=1.2523246,33.794...               25
# 2  https://www.google.com/maps?q=1.2594365,33.766...               25
# 3  https://www.google.com/maps?q=1.2700466,33.703...               25
# 4  https://www.google.com/maps?q=1.2773514,33.738...               25
#
#    processing_success                                 geometry_grid_cell
# 0                True  POLYGON ((33.789087720369345 1.238272846674644...
# 1                True  POLYGON ((33.79807840053194 1.24731652616738, ...
# 2                True  POLYGON ((33.77111699937585 1.2563710620307793...
# 3                True  POLYGON ((33.70820246722493 1.265435561661601,...
# 4                True  POLYGON ((33.74415784726423 1.2744719335032875...

# %%
print("aisa", results_aisa.processing_success.value_counts())
#only one missing (which is a replacement cluster, lets just give the centroid)

print("dwanwana_dokolo", results_dwanwana_dokolo.processing_success.value_counts())

#save. 
#results_aisa.to_csv(TEMP_DATA_DIR / 'aisa_roadpoints.csv')      
#results_dwanwana_dokolo.to_csv(TEMP_DATA_DIR / 'dwanwana_dokolo_roadpoints.csv')      
      

#create a roadpoints dataset 
roadpoints_df=pd.concat([results_aisa, results_dwanwana_dokolo])


print(roadpoints_df.station_name.value_counts(dropna=False)) #seems legit
print(roadpoints_df.shape)
# Out:
# aisa processing_success
# True    70
# Name: count, dtype: int64
# dwanwana_dokolo processing_success
# True    140
# Name: count, dtype: int64
# station_name
# Aisa FM        70
# Dwanwana FM    70
# Dokolo FM      70
# Name: count, dtype: int64
# (210, 15)

# %%
#add adress data for the nearest roadpoints using nomatim/reverse geocoding. 
def get_location_details(lat, lon):
    """
    Get administrative areas/adresses using OpenStreetMap/Nominatim
    """
    geolocator = Nominatim(user_agent="my_app")
    
    try:
        # Make the reverse geocoding request
        location = geolocator.reverse((lat, lon), exactly_one=True)
        if not location:
            return None
            
        # Extract address components
        address = location.raw['address']
        location_data = {'nearest_address_full': location.raw['display_name'],
            'village': address.get('village'),
             'district': address.get('state') or address.get('district'),
             'region': address.get('region'),
             'country': address.get('country'),
             'nearest_village_lat': location.raw['lat'],
             'nearest_village_lon': location.raw['lon'],
         }
        
        return location_data
        
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
#apply to dataframe
results=[]
for index, row in roadpoints_df.iterrows():
    location_data = get_location_details(row['nearest_road_lat'], row['nearest_road_lon'])
    if location_data:
        location_data['grid_id'] = row['grid_id'] #parse the grid id from the original df for indexing/merging. 
        location_data['station_name'] = row['station_name'] #parse the grid id from the original df for indexing/merging. 

        print(location_data)
        results.append(location_data)
        time.sleep(0.01)
# Out:
# {'nearest_address_full': 'Komolo -manga, Pallisa, Eastern Region, Uganda', 'village': 'Komolo -manga', 'district': 'Pallisa', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.2473019', 'nearest_village_lon': '33.7806277', 'grid_id': 21965, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kachede, Pallisa, Eastern Region, Uganda', 'village': 'Kachede', 'district': 'Pallisa', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.2520556960898883', 'nearest_village_lon': '33.795196636310806', 'grid_id': 22136, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kapuwai, Pallisa, Eastern Region, Uganda', 'village': 'Kapuwai', 'district': 'Pallisa', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.262748771751475', 'nearest_village_lon': '33.76613591556418', 'grid_id': 21627, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Odusai, Pallisa, Eastern Region, Uganda', 'village': 'Odusai', 'district': 'Pallisa', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.2697977344875335', 'nearest_village_lon': '33.70383628932957', 'grid_id': 20438, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Komolo Kobwin, Pallisa, Eastern Region, Uganda', 'village': 'Komolo Kobwin', 'district': 'Pallisa', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.2773184575182912', 'nearest_village_lon': '33.7380350760635', 'grid_id': 21119, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Nyakoi -ogalai, Pallisa, Eastern Region, Uganda', 'village': 'Nyakoi -ogalai', 'district': 'Pallisa', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.290022211240704', 'nearest_village_lon': '33.80983004114771', 'grid_id': 22480, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Oboliso -kateki, Pallisa, Eastern Region, Uganda', 'village': 'Oboliso -kateki', 'district': 'Pallisa', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.3059905', 'nearest_village_lon': '33.7819554', 'grid_id': 21972, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kadami, Kumi, Eastern Region, Uganda', 'village': 'Kadami', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.3328145327364909', 'nearest_village_lon': '33.77513260642874', 'grid_id': 21805, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kapuwai, Pallisa, Eastern Region, Uganda', 'village': 'Kapuwai', 'district': 'Pallisa', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.280084726416927', 'nearest_village_lon': '33.71321963613993', 'grid_id': 20609, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kapuwai, Pallisa, Eastern Region, Uganda', 'village': 'Kapuwai', 'district': 'Pallisa', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.288720051086117', 'nearest_village_lon': '33.69493530540597', 'grid_id': 20270, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Ariet, Pallisa, Eastern Region, Uganda', 'village': 'Ariet', 'district': 'Pallisa', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.3175388858178176', 'nearest_village_lon': '33.72280231034398', 'grid_id': 20783, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Olukangor, Ngora, Eastern Region, Uganda', 'village': 'Olukangor', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.38861819369026', 'nearest_village_lon': '33.75750051685578', 'grid_id': 21471, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Atoot Primary School, Komolo, Ngora, Eastern Region, Uganda', 'village': 'Komolo', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.3794348', 'nearest_village_lon': '33.7877332', 'grid_id': 21980, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kaderun, Ngora, Eastern Region, Uganda', 'village': 'Kaderun', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4254033331136737', 'nearest_village_lon': '33.75790229599637', 'grid_id': 21475, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kaderun, Ngora, Eastern Region, Uganda', 'village': 'Kaderun', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4262465', 'nearest_village_lon': '33.7830424', 'grid_id': 21986, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kaderun, Ngora, Eastern Region, Uganda', 'village': 'Kaderun', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4285702493999244', 'nearest_village_lon': '33.76946630876505', 'grid_id': 21646, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Oswara, Ngora, Eastern Region, Uganda', 'village': 'Oswara', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.3704790395742859', 'nearest_village_lon': '33.706408289226054', 'grid_id': 20449, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Tilling, Ngora, Eastern Region, Uganda', 'village': 'Tilling', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4187234', 'nearest_village_lon': '33.7170385', 'grid_id': 20624, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Amese, Serere, Eastern Region, Uganda', 'village': 'Amese', 'district': 'Serere', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4429168643549277', 'nearest_village_lon': '33.63087117057739', 'grid_id': 19097, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Okongora, Pallisa, Eastern Region, Uganda', 'village': 'Okongora', 'district': 'Pallisa', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.2442768', 'nearest_village_lon': '33.8448268', 'grid_id': 23155, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kapuwai, Pallisa, Eastern Region, Uganda', 'village': 'Kapuwai', 'district': 'Pallisa', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.2687375', 'nearest_village_lon': '33.8302398', 'grid_id': 22818, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kabura, Kumi, Eastern Region, Uganda', 'village': 'Kabura', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.2957462812888718', 'nearest_village_lon': '33.882607649995805', 'grid_id': 23841, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kabura, Kumi, Eastern Region, Uganda', 'village': 'Kabura', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.3250874332478124', 'nearest_village_lon': '33.83893586485144', 'grid_id': 22994, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kabura, Kumi, Eastern Region, Uganda', 'village': 'Kabura', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.3332781582128281', 'nearest_village_lon': '33.84765737351996', 'grid_id': 23165, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kabukol Primary School, Kabukol, Kumi, Eastern Region, Uganda', 'village': 'Kabukol', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.3584603', 'nearest_village_lon': '33.8380083', 'grid_id': 22998, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kanyumu Road, Kamachya, Kumi, Eastern Region, Uganda', 'village': 'Kamachya', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.3172342526640528', 'nearest_village_lon': '33.96972892234964', 'grid_id': 25543, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Omerein, Kumi, Eastern Region, Uganda', 'village': 'Omerein', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.3296554', 'nearest_village_lon': '33.922171', 'grid_id': 24525, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kanyumu, Kumi, Eastern Region, Uganda', 'village': 'Kanyumu', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.3501634022942421', 'nearest_village_lon': '33.92711365847891', 'grid_id': 24697, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Saint Charles Akulony Primary School, Lira - Mbale Road, Kapokin, Bugisa sub-region, Ngora, Eastern Region, Uganda', 'village': 'Kapokin', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.385545', 'nearest_village_lon': '34.0014144', 'grid_id': 26061, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Abitibit, Bukedea, Eastern Region, Uganda', 'village': 'Abitibit', 'district': 'Bukedea', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4508370032492799', 'nearest_village_lon': '34.00893307684724', 'grid_id': 26238, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kanyumu Road, Kamachya, Kumi, Eastern Region, Uganda', 'village': 'Kamachya', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.3937330022339602', 'nearest_village_lon': '33.90007821615293', 'grid_id': 24192, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Atekwa, Kumi, Eastern Region, Uganda', 'village': 'Atekwa', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.413363', 'nearest_village_lon': '33.8273259', 'grid_id': 22834, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Atiida, Kumi, Eastern Region, Uganda', 'village': 'Atiida', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4426487', 'nearest_village_lon': '33.9036598', 'grid_id': 24197, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kanyumu Road, Nyero, Kumi, Eastern Region, Uganda', 'village': 'Nyero', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4596981033874654', 'nearest_village_lon': '33.85795190357442', 'grid_id': 23349, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Ajuket, Kumi, Eastern Region, Uganda', 'village': 'Ajuket', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.3784357029304068', 'nearest_village_lon': '33.96459678105555', 'grid_id': 25380, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Atutur, Kumi, Eastern Region, Uganda', 'village': None, 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4027687528723884', 'nearest_village_lon': '33.93928591932226', 'grid_id': 24873, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Obule Primary School, Kanyumu Road, Ogoloi, Kumi, Eastern Region, Uganda', 'village': 'Ogoloi', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4238758', 'nearest_village_lon': '33.9124588', 'grid_id': 24365, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Lira - Mbale Road, Atutur, Bugisa sub-region, Kumi, Eastern Region, Uganda', 'village': None, 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4600720186661424', 'nearest_village_lon': '33.95652320013622', 'grid_id': 25219, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Ocagoro, Kumi, Eastern Region, Uganda', 'village': 'Ocagoro', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4683134049913364', 'nearest_village_lon': '33.99163254684652', 'grid_id': 25900, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Okuoro, Kumi, Eastern Region, Uganda', 'village': 'Okuoro', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.52511', 'nearest_village_lon': '34.0139287', 'grid_id': 26246, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kalengo, Ngora, Eastern Region, Uganda', 'village': 'Kalengo', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4778741435665868', 'nearest_village_lon': '33.8283276272411', 'grid_id': 22841, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Nyero, Kumi, Eastern Region, Uganda', 'village': 'Nyero', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4801653', 'nearest_village_lon': '33.8554564', 'grid_id': 23351, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Oosion, Kumi, Eastern Region, Uganda', 'village': 'Oosion', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.514614376923077', 'nearest_village_lon': '33.87445671538461', 'grid_id': 23695, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Okwangai, Ngora, Eastern Region, Uganda', 'village': 'Okwangai', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5171284', 'nearest_village_lon': '33.8401107', 'grid_id': 23016, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kopelo, Ngora, Eastern Region, Uganda', 'village': 'Kopelo', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4539083', 'nearest_village_lon': '33.7483657', 'grid_id': 21308, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Ngora Institutional Complex C, Ngora, Eastern Region, Uganda', 'village': 'Ngora Institutional Complex C', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.469055071573565', 'nearest_village_lon': '33.7937291251952', 'grid_id': 22160, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Odwarat, Ngora, Eastern Region, Uganda', 'village': 'Odwarat', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.486770219652209', 'nearest_village_lon': '33.784913223998196', 'grid_id': 21992, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Namasagali, Ngora, Eastern Region, Uganda', 'village': 'Namasagali', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5139938829037547', 'nearest_village_lon': '33.794270447862985', 'grid_id': 22165, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kumel, Ngora, Eastern Region, Uganda', 'village': 'Kumel', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5333577', 'nearest_village_lon': '33.8038034', 'grid_id': 22337, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'To Serere, Agu, Ngora, Eastern Region, Uganda', 'village': 'Agu', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4678699628203622', 'nearest_village_lon': '33.71283810099205', 'grid_id': 20630, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Akisim (kelim), Serere, Eastern Region, Uganda', 'village': 'Akisim (kelim)', 'district': 'Serere', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5315223153702435', 'nearest_village_lon': '33.64997716514042', 'grid_id': 19447, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Akisim, Serere, Eastern Region, Uganda', 'village': 'Akisim', 'district': 'Serere', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4691756913236675', 'nearest_village_lon': '33.604843895590506', 'grid_id': 18590, 'station_name': 'Aisa FM'}
# Error: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=1.4962141&lon=33.5868833&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000002D9007FC550>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# {'nearest_address_full': 'Komolo, Ngora, Eastern Region, Uganda', 'village': 'Komolo', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5450223', 'nearest_village_lon': '33.7587113', 'grid_id': 21488, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Ajeelo, Ngora, Eastern Region, Uganda', 'village': 'Ajeelo', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5834312343746244', 'nearest_village_lon': '33.78669550348094', 'grid_id': 22003, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Ajesa, Ngora, Eastern Region, Uganda', 'village': 'Ajesa', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.62791', 'nearest_village_lon': '33.7590055', 'grid_id': 21497, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Oregia-ajepet, Soroti, Eastern Region, Uganda', 'village': 'Oregia-ajepet', 'district': 'Soroti', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5837807', 'nearest_village_lon': '33.6345753', 'grid_id': 19282, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Omulala, Soroti, Eastern Region, Uganda', 'village': 'Omulala', 'district': 'Soroti', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.6318608725456936', 'nearest_village_lon': '33.65815090591901', 'grid_id': 19628, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Oregia-ajepet, Soroti, Eastern Region, Uganda', 'village': 'Oregia-ajepet', 'district': 'Soroti', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5837807', 'nearest_village_lon': '33.6345753', 'grid_id': 19113, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Lira - Mbale Road, Cell F, Soroti, Eastern Region, Uganda', 'village': 'Cell F', 'district': 'Soroti', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.669348127817112', 'nearest_village_lon': '33.71349974235352', 'grid_id': 20652, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Boma South, Kumi, Eastern Region, Uganda', 'village': 'Boma South', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4867933339408859', 'nearest_village_lon': '33.94648875475083', 'grid_id': 25052, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kumi, Eastern Region, Uganda', 'village': None, 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.4869751348888811', 'nearest_village_lon': '33.92859533606347', 'grid_id': 24712, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Kabata, Kumi, Eastern Region, Uganda', 'village': 'Kabata', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5032661819042523', 'nearest_village_lon': '33.909148950296704', 'grid_id': 24374, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Ceele, Kumi, Eastern Region, Uganda', 'village': 'Ceele', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5419821', 'nearest_village_lon': '33.954792', 'grid_id': 25228, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Lira - Mbale Road, Atutur, Bugisa sub-region, Kumi, Eastern Region, Uganda', 'village': None, 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5410644097050508', 'nearest_village_lon': '33.892519942369255', 'grid_id': 24038, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Adul, Ngora, Eastern Region, Uganda', 'village': 'Adul', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5765096348021457', 'nearest_village_lon': '33.884167139390115', 'grid_id': 23872, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Lira - Mbale Road, Atutur, Bugisa sub-region, Ngora, Eastern Region, Uganda', 'village': None, 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5974666733720566', 'nearest_village_lon': '33.82194902093035', 'grid_id': 22684, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Okomion, Ngora, Eastern Region, Uganda', 'village': 'Okomion', 'district': 'Ngora', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.6236293900977947', 'nearest_village_lon': '33.85612414294369', 'grid_id': 23367, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Nyakoi, Kumi, Eastern Region, Uganda', 'village': 'Nyakoi', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.559320021858716', 'nearest_village_lon': '33.95584459801576', 'grid_id': 25230, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Ceele, Kumi, Eastern Region, Uganda', 'village': 'Ceele', 'district': 'Kumi', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.5947188311479044', 'nearest_village_lon': '33.964797180878996', 'grid_id': 25404, 'station_name': 'Aisa FM'}
# {'nearest_address_full': 'Omor, Kaberamaido, Eastern Region, Uganda', 'village': 'Omor', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.6945084068139382', 'nearest_village_lon': '33.14511164104249', 'grid_id': 9945, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Otage, Kaberamaido, Eastern Region, Uganda', 'village': 'Otage', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7211574', 'nearest_village_lon': '33.1684249', 'grid_id': 10457, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Ariebai, Kaberamaido, Eastern Region, Uganda', 'village': 'Ariebai', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7287169', 'nearest_village_lon': '33.2508993', 'grid_id': 11988, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Owerai A, Kaberamaido, Eastern Region, Uganda', 'village': 'Owerai A', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7377243', 'nearest_village_lon': '33.2036785', 'grid_id': 11139, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Amsim B, Kaberamaido, Eastern Region, Uganda', 'village': 'Amsim B', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7479372', 'nearest_village_lon': '33.2543588', 'grid_id': 11991, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Alipa, Kaberamaido, Eastern Region, Uganda', 'village': 'Alipa', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7675034951675843', 'nearest_village_lon': '33.17300192664807', 'grid_id': 10463, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Apili, Kaberamaido, Eastern Region, Uganda', 'village': 'Apili', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7862514160828025', 'nearest_village_lon': '33.22725600270899', 'grid_id': 11485, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Palatao, Kalaki, Eastern Region, Uganda', 'village': 'Palatao', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7210863', 'nearest_village_lon': '33.2986379', 'grid_id': 12838, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Atek, Kaberamaido, Eastern Region, Uganda', 'village': 'Atek', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7855048', 'nearest_village_lon': '33.27319', 'grid_id': 12165, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Atek, Kaberamaido, Eastern Region, Uganda', 'village': 'Atek', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7855048', 'nearest_village_lon': '33.27319', 'grid_id': 12505, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Amati, Dokolo, Northern Region, Uganda', 'village': 'Amati', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.7313164579139682', 'nearest_village_lon': '33.04011525569201', 'grid_id': 7909, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Akora, Kaberamaido, Eastern Region, Uganda', 'village': 'Akora', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7205233', 'nearest_village_lon': '33.095203', 'grid_id': 8928, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Majengo A, Kaberamaido, Eastern Region, Uganda', 'village': 'Majengo A', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7587495940674298', 'nearest_village_lon': '33.15544930671787', 'grid_id': 10122, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Amati, Dokolo, Northern Region, Uganda', 'village': 'Amati', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.776490079389539', 'nearest_village_lon': '33.08373519475955', 'grid_id': 8764, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Amati, Dokolo, Northern Region, Uganda', 'village': 'Amati', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.7839715876197495', 'nearest_village_lon': '33.087277691010655', 'grid_id': 8765, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Obako, Dokolo, Northern Region, Uganda', 'village': 'Obako', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.7672459', 'nearest_village_lon': '33.0579815', 'grid_id': 8423, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Awidi (adeknino), Dokolo, Northern Region, Uganda', 'village': 'Awidi (adeknino)', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.784964886654562', 'nearest_village_lon': '33.041788200969854', 'grid_id': 7915, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Ararak B, Dokolo, Northern Region, Uganda', 'village': 'Ararak B', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.8029871183129493', 'nearest_village_lon': '33.101830615709105', 'grid_id': 9107, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Omodoi B, Kaberamaido, Eastern Region, Uganda', 'village': 'Omodoi B', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8207118', 'nearest_village_lon': '33.1238179', 'grid_id': 9619, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Olumai B, Dokolo, Northern Region, Uganda', 'village': 'Olumai B', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.8539867', 'nearest_village_lon': '33.1080857', 'grid_id': 9283, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Adwongger, Dokolo, Northern Region, Uganda', 'village': 'Adwongger', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.8824019202747957', 'nearest_village_lon': '33.10955724033203', 'grid_id': 9286, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Kaberamaido, Eastern Region, Uganda', 'village': None, 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8202516032711493', 'nearest_village_lon': '33.21057947219572', 'grid_id': 11149, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Omunat A, Kaberamaido, Eastern Region, Uganda', 'village': 'Omunat A', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8557575', 'nearest_village_lon': '33.2103091', 'grid_id': 11153, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Katingi, Kaberamaido, Eastern Region, Uganda', 'village': 'Katingi', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8761502477072853', 'nearest_village_lon': '33.18242661703375', 'grid_id': 10645, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Aoya B, Kaberamaido, Eastern Region, Uganda', 'village': 'Aoya B', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8848774283359009', 'nearest_village_lon': '33.182355481091484', 'grid_id': 10646, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Ocekikot, Dokolo, Northern Region, Uganda', 'village': 'Ocekikot', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.8355111', 'nearest_village_lon': '33.0694889', 'grid_id': 8431, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Oyengopere, Dokolo, Northern Region, Uganda', 'village': 'Oyengopere', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.8674999674290977', 'nearest_village_lon': '33.05661127028753', 'grid_id': 8264, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Adwongdoki, Dokolo, Northern Region, Uganda', 'village': 'Adwongdoki', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.8919967674929288', 'nearest_village_lon': '33.06870288876557', 'grid_id': 8437, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Dokolo, Northern Region, Uganda', 'village': None, 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.8934629202514832', 'nearest_village_lon': '33.13778568034755', 'grid_id': 9797, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Lira - Mbale Road, Omukuceke, Dokolo, Northern Region, Uganda', 'village': 'Omukuceke', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.931889602312982', 'nearest_village_lon': '33.13805731636346', 'grid_id': 9801, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Adagamone, Dokolo, Northern Region, Uganda', 'village': 'Adagamone', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9590349', 'nearest_village_lon': '33.136957', 'grid_id': 9804, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Kaburuburu, Kalaki, Eastern Region, Uganda', 'village': 'Kaburuburu', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.9056142', 'nearest_village_lon': '33.2418381', 'grid_id': 11838, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Saint John Bosco Secondary School, Lira - Mbale Road, Dokolo, Northern Region, Uganda', 'village': None, 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.921676', 'nearest_village_lon': '33.1789228', 'grid_id': 10650, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Amiro, Dokolo, Northern Region, Uganda', 'village': 'Amiro', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9477175', 'nearest_village_lon': '33.2117116', 'grid_id': 11163, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Aceniworo (adagmon), Dokolo, Northern Region, Uganda', 'village': 'Aceniworo (adagmon)', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9686165', 'nearest_village_lon': '33.1908277', 'grid_id': 10825, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Agwata Tidi, Dokolo, Northern Region, Uganda', 'village': 'Agwata Tidi', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9203058', 'nearest_village_lon': '32.9861972', 'grid_id': 6910, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Ajet, Dokolo, Northern Region, Uganda', 'village': 'Ajet', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.966517846367287', 'nearest_village_lon': '33.048465161402056', 'grid_id': 8105, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Ayito (adwoki), Dokolo, Northern Region, Uganda', 'village': 'Ayito (adwoki)', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.993489180101613', 'nearest_village_lon': '33.066419646192195', 'grid_id': 8448, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Apokor, Kalaki, Eastern Region, Uganda', 'village': 'Apokor', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8301255512916808', 'nearest_village_lon': '33.37907093189753', 'grid_id': 14380, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Apari, Kalaki, Eastern Region, Uganda', 'village': 'Apari', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8605649340088037', 'nearest_village_lon': '33.344532040178954', 'grid_id': 13703, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Akarowok, Kaberamaido, Eastern Region, Uganda', 'village': 'Akarowok', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8132598', 'nearest_village_lon': '33.2517736', 'grid_id': 11998, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Omarai, Kaberamaido, Eastern Region, Uganda', 'village': 'Omarai', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.833333', 'nearest_village_lon': '33.25', 'grid_id': 12000, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Odikara, Kalaki, Eastern Region, Uganda', 'village': 'Odikara', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8596722288006728', 'nearest_village_lon': '33.3215257912606', 'grid_id': 13193, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Ocanga, Kalaki, Eastern Region, Uganda', 'village': 'Ocanga', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.886955256556378', 'nearest_village_lon': '33.306019492501875', 'grid_id': 13026, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Opokoro, Kalaki, Eastern Region, Uganda', 'village': 'Opokoro', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8937103581219132', 'nearest_village_lon': '33.36231006070855', 'grid_id': 14047, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Lira - Mbale Road, Apapai, Kalaki, Eastern Region, Uganda', 'village': 'Apapai', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.9372959415768547', 'nearest_village_lon': '33.35323965398996', 'grid_id': 13882, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Ocukai, Kalaki, Eastern Region, Uganda', 'village': 'Ocukai', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.895136360454064', 'nearest_village_lon': '33.33563317920316', 'grid_id': 13537, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Olorok, Kalaki, Eastern Region, Uganda', 'village': 'Olorok', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.9223307473889915', 'nearest_village_lon': '33.33620699267512', 'grid_id': 13540, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Odikara, Kalaki, Eastern Region, Uganda', 'village': 'Odikara', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.946339121006934', 'nearest_village_lon': '33.29356183189515', 'grid_id': 12863, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Aminikwach, Kalaki, Eastern Region, Uganda', 'village': 'Aminikwach', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.9530999', 'nearest_village_lon': '33.3100104', 'grid_id': 13034, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Akworatora, Kalaki, Eastern Region, Uganda', 'village': 'Akworatora', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.9717371', 'nearest_village_lon': '33.2710943', 'grid_id': 12356, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Akisim, Kalaki, Eastern Region, Uganda', 'village': 'Akisim', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '2.020550163995266', 'nearest_village_lon': '33.354189127174934', 'grid_id': 13891, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Olor, Dokolo, Northern Region, Uganda', 'village': 'Olor', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0139341517996745', 'nearest_village_lon': '33.198167184808895', 'grid_id': 11000, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Apado, Dokolo, Northern Region, Uganda', 'village': 'Apado', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.02730294748514', 'nearest_village_lon': '33.235852171539364', 'grid_id': 11682, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Odikara, Dokolo, Northern Region, Uganda', 'village': 'Odikara', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0472605', 'nearest_village_lon': '33.2167219', 'grid_id': 11344, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Omanoabunga, Dokolo, Northern Region, Uganda', 'village': 'Omanoabunga', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.053306', 'nearest_village_lon': '33.2387888', 'grid_id': 11685, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Moru, Kalaki, Eastern Region, Uganda', 'village': 'Moru', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.990650438355231', 'nearest_village_lon': '33.332977393718906', 'grid_id': 13548, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Ojama, Kalaki, Eastern Region, Uganda', 'village': 'Ojama', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '2.011228084658022', 'nearest_village_lon': '33.32941961493173', 'grid_id': 13380, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Angoltok, Kalaki, Eastern Region, Uganda', 'village': 'Angoltok', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '2.028508037082815', 'nearest_village_lon': '33.304631539086536', 'grid_id': 12872, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Adagnyeko (adagnyeko), Dokolo, Northern Region, Uganda', 'village': 'Adagnyeko (adagnyeko)', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0494409', 'nearest_village_lon': '33.2617649', 'grid_id': 12194, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Arwotoryema, Dokolo, Northern Region, Uganda', 'village': 'Arwotoryema', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0669788', 'nearest_village_lon': '33.2527801', 'grid_id': 12026, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Iduny, Dokolo, Northern Region, Uganda', 'village': 'Iduny', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0008164', 'nearest_village_lon': '33.1464205', 'grid_id': 9979, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Abuki, Dokolo, Northern Region, Uganda', 'village': 'Abuki', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.011574909589438', 'nearest_village_lon': '33.12715317200279', 'grid_id': 9640, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Ayito (adwoki), Dokolo, Northern Region, Uganda', 'village': 'Ayito (adwoki)', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.026381622251497', 'nearest_village_lon': '33.08722278507062', 'grid_id': 8792, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Barilwa, Amach, Dokolo, Northern Region, Uganda', 'village': 'Barilwa', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0576423715037713', 'nearest_village_lon': '33.09260517012824', 'grid_id': 8965, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Barilwa, Amach, Lira District, Northern Region, Uganda', 'village': 'Barilwa', 'district': 'Lira District', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0567771987795838', 'nearest_village_lon': '33.038021473372595', 'grid_id': 7945, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Te-ilwa (ocero), Dokolo, Northern Region, Uganda', 'village': 'Te-ilwa (ocero)', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0731775103885246', 'nearest_village_lon': '33.1376305565235', 'grid_id': 9817, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Olio, Agali, Lira District, Northern Region, Uganda', 'village': 'Olio', 'district': 'Lira District', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0970654549285257', 'nearest_village_lon': '33.09143322142083', 'grid_id': 8969, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Olor, Alebtong, Northern Region, Uganda', 'village': 'Olor', 'district': 'Alebtong', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0941266862372796', 'nearest_village_lon': '33.21460941673725', 'grid_id': 11349, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Olor, Alebtong, Northern Region, Uganda', 'village': 'Olor', 'district': 'Alebtong', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.1115287315185634', 'nearest_village_lon': '33.220208408427254', 'grid_id': 11351, 'station_name': 'Dwanwana FM'}
# {'nearest_address_full': 'Owelai, Kaberamaido, Eastern Region, Uganda', 'village': 'Owelai', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.699625', 'nearest_village_lon': '33.1200175', 'grid_id': 9436, 'station_name': 'Dokolo FM'}
# Error: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=1.7136196&lon=33.24643870000001&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000002D904796EF0>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# Error: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=1.740168&lon=33.1912939&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000002D9046E1930>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# Error: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=1.7508671&lon=33.2467094&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000002D904767430>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# {'nearest_address_full': 'Apili, Kaberamaido, Eastern Region, Uganda', 'village': 'Apili', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7877946480718432', 'nearest_village_lon': '33.1822673008061', 'grid_id': 10635, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Kaberamaido, Eastern Region, Uganda', 'village': None, 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7974737943464114', 'nearest_village_lon': '33.17907867954107', 'grid_id': 10636, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Alumai A, Kaberamaido, Eastern Region, Uganda', 'village': 'Alumai A', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7608967', 'nearest_village_lon': '33.2492345', 'grid_id': 11992, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Apokemado, Kaberamaido, Eastern Region, Uganda', 'village': 'Apokemado', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8096820463280323', 'nearest_village_lon': '33.289672536777296', 'grid_id': 12677, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Amolatar, Kaberamaido, Eastern Region, Uganda', 'village': 'Amolatar', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7148887067978105', 'nearest_village_lon': '33.109832339549165', 'grid_id': 9267, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Omor, Kaberamaido, Eastern Region, Uganda', 'village': 'Omor', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7342998', 'nearest_village_lon': '33.1153111', 'grid_id': 9269, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Aguroi, Kaberamaido, Eastern Region, Uganda', 'village': 'Aguroi', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7485201588927164', 'nearest_village_lon': '33.11127701004805', 'grid_id': 9271, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Abola, Kaberamaido, Eastern Region, Uganda', 'village': 'Abola', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.7764713355106985', 'nearest_village_lon': '33.149243255369285', 'grid_id': 9954, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Alit, Dokolo, Northern Region, Uganda', 'village': 'Alit', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.8034066110922167', 'nearest_village_lon': '33.074317835018675', 'grid_id': 8597, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Atugu, Dokolo, Northern Region, Uganda', 'village': 'Atugu', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.7702462223847204', 'nearest_village_lon': '33.02922474792278', 'grid_id': 7743, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Ayoni, Dokolo, Northern Region, Uganda', 'village': 'Ayoni', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.8085116', 'nearest_village_lon': '33.0620027', 'grid_id': 8427, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Abola, Kaberamaido, Eastern Region, Uganda', 'village': 'Abola', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.80300704006514', 'nearest_village_lon': '33.149215115851455', 'grid_id': 9957, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Oyama, Kaberamaido, Eastern Region, Uganda', 'village': 'Oyama', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.836607', 'nearest_village_lon': '33.1211454', 'grid_id': 9451, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Abuli, Dokolo, Northern Region, Uganda', 'village': 'Abuli', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.859367273116313', 'nearest_village_lon': '33.09438596588417', 'grid_id': 8943, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Atwako, Dokolo, Northern Region, Uganda', 'village': 'Atwako', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.876159418462791', 'nearest_village_lon': '33.07459519584536', 'grid_id': 8605, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Alwa, Kaberamaido, Eastern Region, Uganda', 'village': 'Alwa', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.832241736962425', 'nearest_village_lon': '33.173105297485', 'grid_id': 10470, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Odingoi, Kaberamaido, Eastern Region, Uganda', 'village': 'Odingoi', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8593939', 'nearest_village_lon': '33.2285356', 'grid_id': 11493, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Aoya B, Kaberamaido, Eastern Region, Uganda', 'village': 'Aoya B', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8872726807629867', 'nearest_village_lon': '33.18850514790876', 'grid_id': 10816, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Akongodyek, Dokolo, Northern Region, Uganda', 'village': 'Akongodyek', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9027192394136918', 'nearest_village_lon': '33.18532825545719', 'grid_id': 10648, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Adwila (apyennyang), Dokolo, Northern Region, Uganda', 'village': 'Adwila (apyennyang)', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.8505953434379145', 'nearest_village_lon': '33.00655332799721', 'grid_id': 7242, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Oyengopere, Dokolo, Northern Region, Uganda', 'village': 'Oyengopere', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.8780523013425388', 'nearest_village_lon': '33.04035267687386', 'grid_id': 7925, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Anyacoto, Dokolo, Northern Region, Uganda', 'village': 'Anyacoto', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9039771502141078', 'nearest_village_lon': '33.047168166689765', 'grid_id': 8098, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Atama (western Ward), Dokolo, Northern Region, Uganda', 'village': 'Atama (western Ward)', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9107398', 'nearest_village_lon': '33.1530824', 'grid_id': 10139, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Lira - Mbale Road, Omukuceke, Dokolo, Northern Region, Uganda', 'village': 'Omukuceke', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9400803978234822', 'nearest_village_lon': '33.11971186272457', 'grid_id': 9462, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Aolikwec, Dokolo, Northern Region, Uganda', 'village': 'Aolikwec', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9660769', 'nearest_village_lon': '33.1077129', 'grid_id': 9295, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Abia, Kalaki, Eastern Region, Uganda', 'village': 'Abia', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.912285984960571', 'nearest_village_lon': '33.22795104027405', 'grid_id': 11499, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Dokolo, Northern Region, Uganda', 'village': None, 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.921448918802128', 'nearest_village_lon': '33.16456777002689', 'grid_id': 10310, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Acanmac, Dokolo, Northern Region, Uganda', 'village': 'Acanmac', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9431573', 'nearest_village_lon': '33.2144009', 'grid_id': 11332, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Dokolo, Northern Region, Uganda', 'village': None, 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9836167088549677', 'nearest_village_lon': '33.19352709975134', 'grid_id': 10827, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Amialaki Nursery School, Lira - Mbale Road, Dokolo, Northern Region, Uganda', 'village': None, 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9283831', 'nearest_village_lon': '33.0440608', 'grid_id': 8101, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Agwata Tidi, Dokolo, Northern Region, Uganda', 'village': 'Agwata Tidi', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9573217371003224', 'nearest_village_lon': '33.000849232832444', 'grid_id': 7254, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Akuli, Kwania, Northern Region, Uganda', 'village': 'Akuli', 'district': 'Kwania', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9176607', 'nearest_village_lon': '32.9341839', 'grid_id': 6059, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Akuli, Dokolo, Northern Region, Uganda', 'village': 'Akuli', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9654024833890575', 'nearest_village_lon': '32.98024824266819', 'grid_id': 6745, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Ogolai, Kalaki, Eastern Region, Uganda', 'village': 'Ogolai', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8668787', 'nearest_village_lon': '33.3585986', 'grid_id': 14044, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Apokemado, Kaberamaido, Eastern Region, Uganda', 'village': 'Apokemado', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8087939646599624', 'nearest_village_lon': '33.28178296139265', 'grid_id': 12508, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Awimon, Kaberamaido, Eastern Region, Uganda', 'village': 'Awimon', 'district': 'Kaberamaido', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8385961', 'nearest_village_lon': '33.2584476', 'grid_id': 12171, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Omarai, Kalaki, Eastern Region, Uganda', 'village': 'Omarai', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8681173', 'nearest_village_lon': '33.3292579', 'grid_id': 13364, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Ocanga, Kalaki, Eastern Region, Uganda', 'village': 'Ocanga', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8684508553812937', 'nearest_village_lon': '33.28117540457022', 'grid_id': 12514, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Ocukai, Kalaki, Eastern Region, Uganda', 'village': 'Ocukai', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.8936139', 'nearest_village_lon': '33.3455095', 'grid_id': 13707, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Akamtak, Kalaki, Eastern Region, Uganda', 'village': 'Akamtak', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.9413426', 'nearest_village_lon': '33.3697687', 'grid_id': 14222, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Opokoro, Kalaki, Eastern Region, Uganda', 'village': 'Opokoro', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.9145348163171554', 'nearest_village_lon': '33.32809702437029', 'grid_id': 13369, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Kamuriye, Kalaki, Eastern Region, Uganda', 'village': 'Kamuriye', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.9129572795894927', 'nearest_village_lon': '33.25453396779087', 'grid_id': 12009, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Ongole, Kalaki, Eastern Region, Uganda', 'village': 'Ongole', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.9546722', 'nearest_village_lon': '33.3292579', 'grid_id': 13373, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Acida, Kalaki, Eastern Region, Uganda', 'village': 'Acida', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '1.9611058', 'nearest_village_lon': '33.2789611', 'grid_id': 12524, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Awiealem, Dokolo, Northern Region, Uganda', 'village': 'Awiealem', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.993514694050434', 'nearest_village_lon': '33.264235923788426', 'grid_id': 12188, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Anaagogwec, Dokolo, Northern Region, Uganda', 'village': 'Anaagogwec', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9885928014359089', 'nearest_village_lon': '33.21554541150407', 'grid_id': 11338, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Adagnyeko (acanpii), Dokolo, Northern Region, Uganda', 'village': 'Adagnyeko (acanpii)', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0214785', 'nearest_village_lon': '33.1711756', 'grid_id': 10491, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Acoolwor, Dokolo, Northern Region, Uganda', 'village': 'Acoolwor', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0513636704390703', 'nearest_village_lon': '33.21165592044499', 'grid_id': 11174, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Agweng, Dokolo, Northern Region, Uganda', 'village': 'Agweng', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.04727588861794', 'nearest_village_lon': '33.163258345206714', 'grid_id': 10324, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Okwongo-iringo, Dokolo, Northern Region, Uganda', 'village': 'Okwongo-iringo', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0627645', 'nearest_village_lon': '33.1659646', 'grid_id': 10325, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Ogwolo Primary School, Amoru, Kalaki, Eastern Region, Uganda', 'village': 'Amoru', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '2.0008094', 'nearest_village_lon': '33.2978387', 'grid_id': 12869, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Awelomer, Dokolo, Northern Region, Uganda', 'village': 'Awelomer', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0121757480705487', 'nearest_village_lon': '33.263377662294715', 'grid_id': 12190, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Angoltok, Kalaki, Eastern Region, Uganda', 'village': 'Angoltok', 'district': 'Kalaki', 'region': 'Eastern Region', 'country': 'Uganda', 'nearest_village_lat': '2.0307352422592166', 'nearest_village_lon': '33.30720568328362', 'grid_id': 13042, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Abwa, Alebtong, Northern Region, Uganda', 'village': 'Abwa', 'district': 'Alebtong', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0662325279393063', 'nearest_village_lon': '33.30865573491684', 'grid_id': 13046, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Acanyibi, Dokolo, Northern Region, Uganda', 'village': 'Acanyibi', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '1.9764498', 'nearest_village_lon': '33.1444368', 'grid_id': 9976, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Acangweno (abucero), Dokolo, Northern Region, Uganda', 'village': 'Acangweno (abucero)', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0091139623634575', 'nearest_village_lon': '33.10940587106757', 'grid_id': 9300, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Okerkok, Dokolo, Northern Region, Uganda', 'village': 'Okerkok', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0184413884453605', 'nearest_village_lon': '33.102089457735474', 'grid_id': 9131, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Ayito (adwoki), Dokolo, Northern Region, Uganda', 'village': 'Ayito (adwoki)', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.045211878079012', 'nearest_village_lon': '33.154813505717016', 'grid_id': 10154, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Akaidebe B, Amach, Lira District, Northern Region, Uganda', 'village': 'Akaidebe B', 'district': 'Lira District', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0421902101331053', 'nearest_village_lon': '33.00370265959638', 'grid_id': 7433, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Alworo A, Amach, Lira District, Northern Region, Uganda', 'village': 'Alworo A', 'district': 'Lira District', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0684481', 'nearest_village_lon': '32.9892398', 'grid_id': 7095, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Odwonga, Amach, Lira District, Northern Region, Uganda', 'village': 'Odwonga', 'district': 'Lira District', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0932983', 'nearest_village_lon': '33.045277', 'grid_id': 7950, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Acanpii A, Agali, Lira District, Northern Region, Uganda', 'village': 'Acanpii A', 'district': 'Lira District', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.112704709518338', 'nearest_village_lon': '33.118102047038526', 'grid_id': 9481, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Oriocudi, Agali, Lira District, Northern Region, Uganda', 'village': 'Oriocudi', 'district': 'Lira District', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.1243644397356505', 'nearest_village_lon': '33.11049015254601', 'grid_id': 9312, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Barayom (apenyo), Dokolo, Northern Region, Uganda', 'village': 'Barayom (apenyo)', 'district': 'Dokolo', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0822343', 'nearest_village_lon': '33.2183112', 'grid_id': 11348, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Aweikoko, Alebtong, Northern Region, Uganda', 'village': 'Aweikoko', 'district': 'Alebtong', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0983261', 'nearest_village_lon': '33.2318774', 'grid_id': 11690, 'station_name': 'Dokolo FM'}
# {'nearest_address_full': 'Anapakori, Alebtong, Northern Region, Uganda', 'village': 'Anapakori', 'district': 'Alebtong', 'region': None, 'country': 'Uganda', 'nearest_village_lat': '2.0866618784770856', 'nearest_village_lon': '33.29840774523929', 'grid_id': 12878, 'station_name': 'Dokolo FM'}

# %%
#throw in dataframe
results_df=pd.DataFrame(results)
#how many districts
print(results_df.district.value_counts(dropna=False))
#temp outfile save
results_df.to_csv(TEMP_DATA_DIR/'reversegeocod.csv')


roadpoints_address_df=roadpoints_df.merge(results_df, on=['station_name', 'grid_id'], how='left')
# roadpoints_address_df
roadpoints_address_df.shape
# Out:
# district
# Dokolo           61
# Kaberamaido      34
# Kalaki           29
# Kumi             27
# Ngora            22
# Pallisa          12
# Lira District     7
# Alebtong          5
# Soroti            4
# Serere            3
# Bukedea           1
# Kwania            1
# Name: count, dtype: int64
# (210, 22)

# %%
print(roadpoints_address_df.village.value_counts(dropna=False))

#12 clusters where we could not find a nearest village, but they mostly have some other marker (e.g. like a school on open streetmap)
#Calcululate the distance to the nearest village to get an idea of how reliable this is? 

def calculate_distance(row):
    '''Calculates distance in km between 2 coordinates, returns None if coordinates are invalid'''
    try:
        point_road = (row['nearest_road_lat'], row['nearest_road_lon'])
        point_village = (row['nearest_village_lat'], row['nearest_village_lon'])
        return geodesic(point_road, point_village).kilometers
    except (ValueError, TypeError):
        return None



roadpoints_address_df['dist_point_to_nearest_address_km'] = roadpoints_address_df.apply(calculate_distance, axis=1)
# #bit of clean-up
# Out:
# village
# None                12
# Kapuwai              4
# NaN                  4
# Kabura               3
# Ayito (adwoki)       3
#                     ..
# Acanpii A            1
# Oriocudi             1
# Barayom (apenyo)     1
# Aweikoko             1
# Anapakori            1
# Name: count, Length: 159, dtype: int64
#      grid_id station_name  buffer_km  est_population_2020  centroid_lat  \
# 0      21965      Aisa FM       25.0           412.028381      1.242797
# 1      22136      Aisa FM       25.0           867.115967      1.251841
# 2      21627      Aisa FM       25.0          1342.766846      1.260896
# 3      20438      Aisa FM       25.0          1109.628174      1.269960
# 4      21119      Aisa FM       25.0           802.255127      1.278996
# ..       ...          ...        ...                  ...           ...
# 205     9481    Dokolo FM       25.0           488.350555      2.111445
# 206     9312    Dokolo FM       25.0           304.447693      2.120492
# 207    11348    Dokolo FM       25.0           424.834106      2.084292
# 208    11690    Dokolo FM       25.0           219.438843      2.102384
# 209    12878    Dokolo FM       25.0           479.428192      2.084279
#
#      centroid_lon                                 centroid_maps_link  \
# 0       33.784595  https://www.google.com/maps?q=1.24279738383433...
# 1       33.793586  https://www.google.com/maps?q=1.25184107840705...
# 2       33.766624  https://www.google.com/maps?q=1.26089560634678...
# 3       33.703710  https://www.google.com/maps?q=1.26996006966729...
# 4       33.739665  https://www.google.com/maps?q=1.27899647711486...
# ..            ...                                                ...
# 205     33.119498  https://www.google.com/maps?q=2.11144452049034...
# 206     33.110505  https://www.google.com/maps?q=2.12049236240166...
# 207     33.218414  https://www.google.com/maps?q=2.08429233098936...
# 208     33.236402  https://www.google.com/maps?q=2.10238394890964...
# 209     33.299347  https://www.google.com/maps?q=2.08427895058338...
#
#     cluster_type  nearest_road_lat  nearest_road_lon  ...  processing_success  \
# 0           main          1.243939         33.782163  ...                True
# 1           main          1.252325         33.794062  ...                True
# 2    replacement          1.259437         33.766239  ...                True
# 3           main          1.270047         33.703725  ...                True
# 4    replacement          1.277351         33.738072  ...                True
# ..           ...               ...               ...  ...                 ...
# 205  replacement          2.111613         33.118540  ...                True
# 206  replacement          2.119180         33.109078  ...                True
# 207  replacement          2.084239         33.217747  ...                True
# 208         main          2.101423         33.236623  ...                True
# 209  replacement          2.084783         33.298809  ...                True
#
#                                     geometry_grid_cell  \
# 0    POLYGON ((33.789087720369345 1.238272846674644...
# 1    POLYGON ((33.79807840053194 1.24731652616738, ...
# 2    POLYGON ((33.77111699937585 1.2563710620307793...
# 3    POLYGON ((33.70820246722493 1.265435561661601,...
# 4    POLYGON ((33.74415784726423 1.2744719335032875...
# ..                                                 ...
# 205  POLYGON ((33.12399361252331 2.1069205986189536...
# 206  POLYGON ((33.115001510876404 2.115968464354523...
# 207  POLYGON ((33.222909959580846 2.079768151713362...
# 208  POLYGON ((33.24089783062235 2.0978597189140844...
# 209  POLYGON ((33.303842776342165 2.079754568434286...
#
#                                   nearest_address_full           village  \
# 0       Komolo -manga, Pallisa, Eastern Region, Uganda     Komolo -manga
# 1             Kachede, Pallisa, Eastern Region, Uganda           Kachede
# 2             Kapuwai, Pallisa, Eastern Region, Uganda           Kapuwai
# 3              Odusai, Pallisa, Eastern Region, Uganda            Odusai
# 4       Komolo Kobwin, Pallisa, Eastern Region, Uganda     Komolo Kobwin
# ..                                                 ...               ...
# 205  Acanpii A, Agali, Lira District, Northern Regi...         Acanpii A
# 206  Oriocudi, Agali, Lira District, Northern Regio...          Oriocudi
# 207  Barayom (apenyo), Dokolo, Northern Region, Uganda  Barayom (apenyo)
# 208        Aweikoko, Alebtong, Northern Region, Uganda          Aweikoko
# 209       Anapakori, Alebtong, Northern Region, Uganda         Anapakori
#
#           district          region country nearest_village_lat  \
# 0          Pallisa  Eastern Region  Uganda           1.2473019
# 1          Pallisa  Eastern Region  Uganda  1.2520556960898883
# 2          Pallisa  Eastern Region  Uganda   1.262748771751475
# 3          Pallisa  Eastern Region  Uganda  1.2697977344875335
# 4          Pallisa  Eastern Region  Uganda  1.2773184575182912
# ..             ...             ...     ...                 ...
# 205  Lira District            None  Uganda   2.112704709518338
# 206  Lira District            None  Uganda  2.1243644397356505
# 207         Dokolo            None  Uganda           2.0822343
# 208       Alebtong            None  Uganda           2.0983261
# 209       Alebtong            None  Uganda  2.0866618784770856
#
#     nearest_village_lon dist_point_to_nearest_address_km
# 0            33.7806277                         0.409300
# 1    33.795196636310806                         0.129720
# 2     33.76613591556418                         0.366433
# 3     33.70383628932957                         0.030163
# 4      33.7380350760635                         0.005483
# ..                  ...                              ...
# 205  33.118102047038526                         0.130134
# 206   33.11049015254601                         0.594420
# 207          33.2183112                         0.230331
# 208          33.2318774                         0.629234
# 209   33.29840774523929                         0.212512
#
# [210 rows x 23 columns]

# %%
roadpoints_address_df.columns
# Out:
# Index(['grid_id', 'station_name', 'buffer_km', 'est_population_2020',
#        'centroid_lat', 'centroid_lon', 'centroid_maps_link', 'cluster_type',
#        'nearest_road_lat', 'nearest_road_lon', 'distance_to_road',
#        'nearest_road_maps_link', 'found_at_radius', 'processing_success',
#        'geometry_grid_cell', 'nearest_address_full', 'village', 'district',
#        'region', 'country', 'nearest_village_lat', 'nearest_village_lon',
#        'dist_point_to_nearest_address_km'],
#       dtype='object')

# %%
from shapely import wkt
#create a geo column. 
_roadpoints_address_df=roadpoints_address_df
_roadpoints_address_df['geometry'] = roadpoints_address_df['geometry_grid_cell'].apply(wkt.loads)
_roadpoints_address_df=_roadpoints_address_df.drop(columns='geometry_grid_cell')
enumeration_area_data=gpd.GeoDataFrame(_roadpoints_address_df, geometry='geometry', crs=sampled_clusters_gdf.crs)

# %%
output_path=PROCESSED_DATA_DIR/'enumeration_area_data.gpkg'
crs=sampled_clusters_gdf.crs

enumeration_area_data.to_file(output_path, driver='GPKG', layer='grid_cells') #grid_cells contains the whole dataset. 
centroid_gdf = gpd.GeoDataFrame(
        enumeration_area_data[['grid_id', 'station_name', 'cluster_type',  'centroid_lat', 'centroid_lon', 'centroid_maps_link']],
        geometry=gpd.points_from_xy(
            enumeration_area_data['centroid_lon'],
            enumeration_area_data['centroid_lat']
        ),
        crs=crs
    )
centroid_gdf.to_file(output_path, driver='GPKG', layer='centroids')

    # Create and save road points layer
road_points = gpd.GeoDataFrame(
        enumeration_area_data[['grid_id', 'station_name', 'nearest_road_lat', 'nearest_road_lon', 'distance_to_road', 'nearest_road_maps_link']],
        geometry=gpd.points_from_xy(
            enumeration_area_data['nearest_road_lon'],
            enumeration_area_data['nearest_road_lat']
        ),
        crs=crs
    )

road_points.to_file(output_path, driver='GPKG', layer='road_points')
    
    # Create and nearest village points layer
nearest_village_gdf = gpd.GeoDataFrame(
        enumeration_area_data[['grid_id', 'station_name','nearest_address_full', 'village', 'district',
       'region', 'country', 'nearest_village_lat', 'nearest_village_lon',
       'dist_point_to_nearest_address_km']],
        geometry=gpd.points_from_xy(
            enumeration_area_data['nearest_village_lon'],
            enumeration_area_data['nearest_village_lat']
        ),
        crs=crs
    )

nearest_village_gdf.to_file(output_path, driver='GPKG', layer='village_points')

# %%
#check how the geopackage works with multiple layers. 

#test=gpd.read_file(PROCESSED_DATA_DIR/'enumeration_area_data.gpkg')
#test

# %%
# def create_enumeration_area_map(row):
#     """
#     Create a map for a single enumeration area showing:
#     1. The nearest road point
#     2. The grid cell geometry
#     3. The centroid
    
#     Parameters:
#     row: A single row from the results DataFrame
#     """
#     import folium
#     from shapely import wkt
    
#     # Convert WKT string back to geometry
#     grid_geometry = wkt.loads(row.geometry)
    
#     # Create a map centered on the nearest road point (if it exists) or centroid
#     if row.nearest_road_lat and row.nearest_road_lon:
#         center_lat, center_lon = row.nearest_road_lat, row.nearest_road_lon
#     else:
#         center_lat, center_lon = row.centroid_lat, row.centroid_lon
        
#     m = folium.Map(
#         location=[center_lat, center_lon],
#         zoom_start=17,
#         tiles='https://mt1.google.com/vt/lyrs=m&x={x}&y={y}&z={z}',
#         attr='Google Maps'
#     )
    
#     # Add the grid cell geometry
#     folium.GeoJson(
#         grid_geometry.__geo_interface__,
#         style_function=lambda x: {
#             'fillColor': '#ffaf00',
#             'color': '#ff0000',
#             'weight': 2,
#             'fillOpacity': 0.1
#         },
#         popup=f"Grid ID: {row.grid_id}"
#     ).add_to(m)
    
#     # Add the centroid point
#     folium.CircleMarker(
#         location=[row.centroid_lat, row.centroid_lon],
#         radius=6,
#         color='blue',
#         fill=True,
#         popup='Centroid'
#     ).add_to(m)
    
#     # Add the nearest road point if it exists
#     if row.nearest_road_lat and row.nearest_road_lon:
#         folium.CircleMarker(
#             location=[row.nearest_road_lat, row.nearest_road_lon],
#             radius=6,
#             color='red',
#             fill=True,
#             popup=f'Nearest Road Point (Distance: {row.distance_to_road:.1f}m)'
#         ).add_to(m)
        
#         # Add a line connecting centroid to nearest road point
#         folium.PolyLine(
#             locations=[
#                 [row.centroid_lat, row.centroid_lon],
#                 [row.nearest_road_lat, row.nearest_road_lon]
#             ],
#             weight=2,
#             color='red',
#             opacity=0.8
#         ).add_to(m)
    
#     # Add a legend
#     legend_html = '''
#     <div style="position: fixed; bottom: 50px; left: 50px; z-index: 1000; 
#          background-color: white; padding: 10px; border: 2px solid grey; border-radius: 5px;">
#         <p><i style="background: red; width: 10px; height: 10px; display: inline-block; border-radius: 50%;"></i> Nearest Road</p>
#         <p><i style="background: blue; width: 10px; height: 10px; display: inline-block; border-radius: 50%;"></i> Centroid</p>
#         <p><i style="border: 2px solid red; width: 10px; height: 10px; display: inline-block;"></i> Grid Boundary</p>
#     </div>
#     '''
#     m.get_root().html.add_child(folium.Element(legend_html))
    
#     return m

# # Create maps for all enumeration areas
# for idx, row in results_df.iterrows():
#     m = create_enumeration_area_map(row)
#     m.save(f'enumeration_area_map_{row.grid_id}.html')

# # Or test with just one area
# test_map = create_enumeration_area_map(results_df.iloc[0])
# test_map.save('test_enumeration_area_map.html')
