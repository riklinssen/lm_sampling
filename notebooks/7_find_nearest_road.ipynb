# %%
import googlemaps
from dotenv import load_dotenv
import os
import ast
import numpy as np
from geopy.distance import geodesic
import pandas as pd
import geopandas as gpd
import time
from pathlib import Path

PROJECT_ROOT = Path().absolute().parent
DATA_DIR = PROJECT_ROOT / 'data'
RAW_DATA_DIR = DATA_DIR / 'raw'
PROCESSED_DATA_DIR = DATA_DIR / 'processed'
TEMP_DATA_DIR = DATA_DIR / 'temp'

#load in data 
sampled_clusters_gdf=gpd.read_file(PROCESSED_DATA_DIR/'sampled_clusters.gpkg')
sampled_clusters_gdf.station_name.unique()
sampled_clusters_gdf

#split this up in batches, dwanwana dokolo first then aisa fm. 

dwanwana_dokolo_sampled_clusters_gdf=sampled_clusters_gdf.loc[sampled_clusters_gdf['station_name'].isin(['Dwanwana FM', 'Dokolo FM'])]
aisa_sampled_clusters_gdf=sampled_clusters_gdf.loc[sampled_clusters_gdf['station_name']=='Aisa FM']
#['Aisa FM', 'Dwanwana FM', 'Dokolo FM']
# Load API key
load_dotenv()
api_key = os.getenv('GOOGLE_MAPS_API_KEY')
gmaps = googlemaps.Client(key=api_key)

def get_points_on_circle(center_lat, center_lon, radius_meters, num_points=4):
    """Generate points on a circle around the center point."""
    radius_deg = radius_meters / 111000 #convert degrees to meters (1 degree ~ 111000 meters)
    
    points = []
    for i in range(num_points):
        angle = 2 * np.pi * i / num_points # create evenly spaced points, calculate the angle where to place te point, circle is 2 pi radians (360 degrees), divide by number of points to evenly space out. 
        lat = center_lat + radius_deg * np.cos(angle) #cosine gives north south position (constant across globe-->latitude)
        lon = center_lon + radius_deg * np.sin(angle) / np.cos(np.radians(center_lat)) # longitude east west component, adjust for curvature by --> dividing by cosine latitude as east west 'shrinks'  at higher latitudes (and we'd otherwise draw an oval)
        points.append((lat, lon))
    
    return points

def find_nearest_road(center_lat, center_lon, gmaps_client, verbose=False):
    """
    Find the nearest road point to a given centroid.
    Stops searching as soon as a road is found in the first radius.
    """
    try:
        # Define search radii
        search_radii = [25, 50, 100, 150, 200] #define search radii, draw a circle around the centroid. 
        
        if verbose:
            print(f"\nOriginal centroid (lat, lon): {center_lat}, {center_lon}") 
        
        closest_point = None
        min_distance = float('inf')
        
        # Search at increasing radii
        for radius in search_radii:
            if verbose:
                print(f"\nSearching at {radius} meters radius...")
            
            num_points = 4 if radius <= 50 else 8 #get 8 points on the circle
            test_points = get_points_on_circle(center_lat, center_lon, radius_meters=radius, num_points=num_points) 
            
            road_found = False  # Flag for finding any road, start at fale. 
            
            for i, origin in enumerate(test_points):
                if verbose:
                    print(f"Trying direction search {i+1}/{num_points} at {radius}m radius")
                
                destination = (center_lat, center_lon)
                
                # Get directions response object from the API. 
                directions_result = gmaps_client.directions(
                    origin=origin,
                    destination=destination,
                    mode="driving"
                )
                print(directions_result)
                if directions_result:
                    steps = directions_result[0]['legs'][0]['steps'] #api gives directions in results and steps as json object/dictionary
                    ##[{'bounds': {'northeast': {'lat': 2.120286, 'lng': 33.2175956}, 'southwest': {'lat': 2.120286, 'lng': 33.2175956}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 2.120286, 'lng': 33.2175956}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 2.120286, 'lng': 33.2175956}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 2.120286, 'lng': 33.2175956}, 'html_instructions': 'Head', 'polyline': {'points': 'yb}K_yviE'}, 'start_location': {'lat': 2.120286, 'lng': 33.2175956}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'yb}K_yviE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]

                    last_step = steps[-1] #take the last step capture the last point before moving off the road. 
                    
                    road_lat = last_step['start_location']['lat'] #capture the coordinates of the point where the directions leave the road (last step), latitude
                    road_lon = last_step['start_location']['lng'] #and longitude
                    #calculate the distance between 2 points using geodesic, to establish what the closest 'leave the road point'  is to the centroid. 
                    distance = geodesic(
                        (center_lat, center_lon), 
                        (road_lat, road_lon)
                    ).meters
                    
                    if verbose:
                        print(f"Found road point at distance: {distance:.1f}m")
                    
                    road_found = True
                    
                    if distance < min_distance: #get the minumum distance if so, get the road lat and lon. 
                        min_distance = distance
                        closest_point = {
                            'lat': road_lat,
                            'lon': road_lon,
                            'distance': distance,
                            'found_at_radius': radius
                        }
            
            # If we found any road in this radius, stop searching
            if road_found and radius == 25:  # Only stop if we found a road in the first radius
                if verbose:
                    print(f"\nFound road within first radius ({radius}m), stopping search")
                break
        
        return closest_point
                
    except Exception as e:
        if verbose:
            print(f"Error: {e}")
        return None

# %%
def process_all_clusters(sampled_clusters_gdf):
    """
    Process all clusters to find nearest roads for their centroids.
    Returns a DataFrame with results.
    """
    # Initialize results list
    results = []
    
    # Total number of clusters for progress tracking
    total_clusters = len(sampled_clusters_gdf)
    print(f"Starting to process {total_clusters} clusters...")
    
    for idx, row in sampled_clusters_gdf.iterrows():
        print(f"\nProcessing {idx+1}/{total_clusters}: grid_id {row.grid_id}")
        
        try:
            # Get centroid coordinates
            coord_tuple = ast.literal_eval(row.centroid_lon_lat)
            center_lat, center_lon = coord_tuple[1], coord_tuple[0]
            
            # Find nearest road
            closest_point = find_nearest_road(center_lat, center_lon, gmaps, verbose=True)
            
            # Store results
            result = {
                'grid_id': row.grid_id,
                'station_name': row.station_name,
                'buffer_km':row.buffer_km,
                'est_population_2020':row.population_count,
                'centroid_lat': center_lat,
                'centroid_lon': center_lon,
                'centroid_maps_link': f"https://www.google.com/maps?q={center_lat},{center_lon}",
                'cluster_type': row.cluster_type,
                'nearest_road_lat': closest_point['lat'] if closest_point else None,
                'nearest_road_lon': closest_point['lon'] if closest_point else None,
                'distance_to_road': closest_point['distance'] if closest_point else None,
                'nearest_road_maps_link': (f"https://www.google.com/maps?q={closest_point['lat']},{closest_point['lon']}" 
                                         if closest_point else None),
                'found_at_radius': closest_point['found_at_radius'] if closest_point else None,
                'processing_success': True if closest_point else False,
                'geometry_grid_cell': row.geometry.wkt  
            }
            
            results.append(result)
            
            # small delay to avoid hitting API limits/overflooding API.
            time.sleep(0.1)
            
        except Exception as e:
            print(f"Error processing grid_id {row.grid_id}: {e}") #check for weird stuff happening. 
            # store error result
            result = {
                'grid_id': row.grid_id,
                'station_name': row.station_name,
                'buffer_km':row.buffer_km,
                'est_population_2020':row.population_count,
                'centroid_lat': center_lat,
                'centroid_lon': center_lon,
                'centroid_maps_link': f"https://www.google.com/maps?q={center_lat},{center_lon}",
                'cluster_type': row.cluster_type,
                'nearest_road_lat': None,
                'nearest_road_lon': None,
                'distance_to_road': None,
                'nearest_road_maps_link': None,
                'found_at_radius': None,
                'processing_success': False,
                'geometry_grid_cell': row.geometry.wkt  
            }
            results.append(result)
    
    # Convert results to DataFrame and return
    return pd.DataFrame(results)

# API calls dwanwana_dokolo:
results_dwanwana_dokolo = process_all_clusters(dwanwana_dokolo_sampled_clusters_gdf)

# 560 requests for largest set <5 dollars in credit.
# Out:
# Starting to process 140 clusters...
#
# Processing 71/140: grid_id 8263
#
# Original centroid (lat, lon): 1.8581265161490297, 33.056539360415755
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.8585298, 'lng': 33.0564973}, 'southwest': {'lat': 1.8580657, 'lng': 33.0562114}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '79 m', 'value': 79}, 'duration': {'text': '1 min', 'value': 17}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.8580657, 'lng': 33.0563314}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.8585298, 'lng': 33.0564973}, 'steps': [{'distance': {'text': '33 m', 'value': 33}, 'duration': {'text': '1 min', 'value': 3}, 'end_location': {'lat': 1.8584586, 'lng': 33.0562114}, 'html_instructions': 'Head <b>west</b>', 'polyline': {'points': 'y~iJcjwhEBRHd@'}, 'start_location': {'lat': 1.8585298, 'lng': 33.0564973}, 'travel_mode': 'DRIVING'}, {'distance': {'text': '46 m', 'value': 46}, 'duration': {'text': '1 min', 'value': 14}, 'end_location': {'lat': 1.8580657, 'lng': 33.0563314}, 'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Destination will be on the left</div>', 'maneuver': 'turn-left', 'polyline': {'points': 'k~iJihwhE|@SNC'}, 'start_location': {'lat': 1.8584586, 'lng': 33.0562114}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'y~iJcjwhELx@lAW'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 51.8m
# Trying direction search 2/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.8580657, 'lng': 33.0563492}, 'southwest': {'lat': 1.858005, 'lng': 33.0563314}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '7 m', 'value': 7}, 'duration': {'text': '1 min', 'value': 2}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.8580657, 'lng': 33.0563314}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.858005, 'lng': 33.0563492}, 'steps': [{'distance': {'text': '7 m', 'value': 7}, 'duration': {'text': '1 min', 'value': 2}, 'end_location': {'lat': 1.8580657, 'lng': 33.0563314}, 'html_instructions': 'Head <b>north</b>', 'polyline': {'points': 'o{iJeiwhEMB'}, 'start_location': {'lat': 1.858005, 'lng': 33.0563492}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'o{iJeiwhEMB'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 25.1m
# Trying direction search 3/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.8580657, 'lng': 33.0563922}, 'southwest': {'lat': 1.8578583, 'lng': 33.0563314}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '24 m', 'value': 24}, 'duration': {'text': '1 min', 'value': 6}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.8580657, 'lng': 33.0563314}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.8578583, 'lng': 33.0563922}, 'steps': [{'distance': {'text': '24 m', 'value': 24}, 'duration': {'text': '1 min', 'value': 6}, 'end_location': {'lat': 1.8580657, 'lng': 33.0563314}, 'html_instructions': 'Head <b>north</b>', 'polyline': {'points': 'sziJmiwhEi@J'}, 'start_location': {'lat': 1.8578583, 'lng': 33.0563922}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'sziJmiwhEi@J'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 33.9m
# Trying direction search 4/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.8581264, 'lng': 33.0563314}, 'southwest': {'lat': 1.8580657, 'lng': 33.0563137}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '7 m', 'value': 7}, 'duration': {'text': '1 min', 'value': 2}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.8580657, 'lng': 33.0563314}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.8581264, 'lng': 33.0563137}, 'steps': [{'distance': {'text': '7 m', 'value': 7}, 'duration': {'text': '1 min', 'value': 2}, 'end_location': {'lat': 1.8580657, 'lng': 33.0563314}, 'html_instructions': 'Head <b>south</b>', 'polyline': {'points': 'i|iJ}hwhEJC'}, 'start_location': {'lat': 1.8581264, 'lng': 33.0563137}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'i|iJ}hwhEJC'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 25.1m
#
# Found road within first radius (25m), stopping search
#
# Processing 72/140: grid_id 9989
#
# Original centroid (lat, lon): 2.093347890770116, 33.14647425120548
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 2.0943889, 'lng': 33.1471562}, 'southwest': {'lat': 2.0943889, 'lng': 33.1471562}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 2.0943889, 'lng': 33.1471562}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 2.0943889, 'lng': 33.1471562}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 2.0943889, 'lng': 33.1471562}, 'html_instructions': 'Head', 'polyline': {'points': '}`xKw`iiE'}, 'start_location': {'lat': 2.0943889, 'lng': 33.1471562}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': '}`xKw`iiE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 137.9m
# Trying direction search 2/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 2.
, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'gloImd`iEOV'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 20.3m
# Trying direction search 4/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.7226145, 'lng': 33.1015541}, 'southwest': {'lat': 1.7225238, 'lng': 33.1013974}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '20 m', 'value': 20}, 'duration': {'text': '1 min', 'value': 2}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.7225238, 'lng': 33.1015541}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.7226145, 'lng': 33.1013974}, 'steps': [{'distance': {'text': '20 m', 'value': 20}, 'duration': {'text': '1 min', 'value': 2}, 'end_location': {'lat': 1.7225238, 'lng': 33.1015541}, 'html_instructions': 'Head <b>southeast</b>', 'polyline': {'points': 'imoIwb`iEDKBEDI@A'}, 'start_location': {'lat': 1.7226145, 'lng': 33.1013974}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'imoIwb`iEP]'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 24.2m
#
# Found road within first radius (25m), stopping search
#
# Processing 76/140: grid_id 9098
#
# Original centroid (lat, lon): 1.7224163330186657, 33.101489071586776
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.7225822, 'lng': 33.1015541}, 'southwest': {'lat': 1.7225238, 'lng': 33.1014585}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '12 m', 'value': 12}, 'duration': {'text': '1 min', 'value': 2}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.7225238, 'lng': 33.1015541}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.7225822, 'lng': 33.1014585}, 'steps': [{'distance': {'text': '12 m', 'value': 12}, 'duration': {'text': '1 min', 'value': 2}, 'end_location': {'lat': 1.7225238, 'lng': 33.1015541}, 'html_instructions': 'Head <b>southeast</b>', 'polyline': {'points': 'cmoIcc`iEBEDI@A'}, 'start_location': {'lat': 1.7225822, 'lng': 33.1014585}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'cmoIcc`iEJQ'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 18.7m
# Trying direction search 2/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.7225238, 'lng': 33.1017136}, 'southwest': {'lat': 1.722415, 'lng': 33.1015541}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '21 m', 'value': 21}, 'duration': {'text': '1 min', 'value': 3}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.7225238, 'lng': 33.1015541}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.722415, 'lng': 33.1017136}, 'steps': [{'distance': {'text': '21 m', 'value': 21}, 'duration': {'text': '1 min', 'value': 3}, 'end_location': {'lat': 1.7225238, 'lng': 33.1015541}, 'html_instructions': 'Head <b>northwest</b>', 'polyline': {'points': 'cloIud`iECFKNCF'}, 'start_location': {'lat': 1.722415, 'lng': 33.1017136}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'cloIud`iES^'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 25.0m
# Trying direction search 3/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.7225238, 'lng': 33.1016701}, 'southwest': {'lat': 1.7224419, 'lng': 33.1015541}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '16 m', 'value': 16}, 'duration': {'text': '1 min', 'value': 2}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.7225238, 'lng': 33.1015541}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.7224419, 'lng': 33.1016701}, 'steps': [{'distance': {'text': '16 m', 'value': 16}, 'duration': {'text': '1 min', 'value': 2}, 'end_location': {'lat': 1.7225238, 'lng': 33.1015541}, 'html_instructions': 'Head <b>northwest</b>', 'polyline': {'points': 'gloImd`iEKNCF'}, 'start_location': {'lat': 1.7224419, 'lng': 33.1016701}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'gloImd`iEOV'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 20.3m
# Trying direction search 4/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.7226145, 'lng': 33.1015541}, 'southwest': {'lat': 1.7225238, 'lng': 33.1013974}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '20 m', 'value': 20}, 'duration': {'text': '1 min', 'value': 2}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.7225238, 'lng': 33.1015541}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.7226145, 'lng': 33.1013974}, 'steps': [{'distance': {'text': '20 m', 'value': 20}, 'duration': {'text': '1 min', 'value': 2}, 'end_location': {'lat': 1.7225238, 'lng': 33.1015541}, 'html_instructions': 'Head <b>southeast</b>', 'polyline': {'points': 'imoIwb`iEDKBEDI@A'}, 'start_location': {'lat': 1.7226145, 'lng': 33.1013974}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'imoIwb`iEP]'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 24.2m
#
# Found road within first radius (25m), stopping search
#
# Processing 77/140: grid_id 11989
#
# Original centroid (lat, lon): 1.7314491198709083, 33.25433279037961
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.7318859, 'lng': 33.2538828}, 'southwest': {'lat': 1.7316422, 'lng': 33.2537834}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '29 m', 'value': 29}, 'duration': {'text': '1 min', 'value': 7}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.7316422, 'lng': 33.2537834}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.7318859, 'lng': 33.2538828}, 'steps': [{'distance': {'text': '29 m', 'value': 29}, 'duration': {'text': '1 min', 'value': 7}, 'end_location': {'lat': 1.7316422, 'lng': 33.2537834}, 'html_instructions': 'Head <b>southwest</b>', 'polyline': {'points': 'igqIw{}iEVHXH'}, 'start_location': {'lat': 1.7318859, 'lng': 33.2538828}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'igqIw{}iEp@R'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 69.6m
# Trying direction search 2/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.7315136, 'lng': 33.2546704}, 'southwest': {'lat': 1.7302527, 'lng': 33.2535403}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '0.3 km', 'value': 281}, 'duration': {'text': '1 min', 'value': 66}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.7315136, 'lng': 33.2537381}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.7307278, 'lng': 33.254551}, 'steps': [{'distance': {'text': '50 m', 'value': 50}, 'duration': {'text': '1 min', 'value': 12}, 'end_location': {'lat': 1.7302903, 'lng': 33.2546729}, 'html_instructions': 'Head <b>south</b>', 'polyline': {'points': 'a`qI}_~iEvAW'}, 'start_location': {'lat': 1.7307278, 'lng': 33.254551}, 'travel_mode': 'DRIVING'}, {'distance': {'text': '0.2 km', 'value': 156}, 'duration': {'text': '1 min', 'value': 28}, 'end_location': {'lat': 1.7308747, 'lng': 33.2535403}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 
[{'distance': {'text': '11 m', 'value': 11}, 'duration': {'text': '1 min', 'value': 3}, 'end_location': {'lat': 2.120286, 'lng': 33.2175956}, 'html_instructions': 'Head <b>south</b>', 'polyline': {'points': 'kc}KwxviEPG'}, 'start_location': {'lat': 2.1203809, 'lng': 33.2175596}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'kc}KwxviEPG'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 96.3m
# Trying direction search 2/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 2.120286, 'lng': 33.2175956}, 'southwest': {'lat': 2.120286, 'lng': 33.2175956}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 2.120286, 'lng': 33.2175956}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 2.120286, 'lng': 33.2175956}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 2.120286, 'lng': 33.2175956}, 'html_instructions': 'Head', 'polyline': {'points': 'yb}K_yviE'}, 'start_location': {'lat': 2.120286, 'lng': 33.2175956}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'yb}K_yviE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 94.1m
# Trying direction search 3/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 2.120286, 'lng': 33.2175956}, 'southwest': {'lat': 2.120286, 'lng': 33.2175956}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 2.120286, 'lng': 33.2175956}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 2.120286, 'lng': 33.2175956}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 2.120286, 'lng': 33.2175956}, 'html_instructions': 'Head', 'polyline': {'points': 'yb}K_yviE'}, 'start_location': {'lat': 2.120286, 'lng': 33.2175956}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'yb}K_yviE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 94.1m
# Trying direction search 4/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 2.120286, 'lng': 33.2175956}, 'southwest': {'lat': 2.120286, 'lng': 33.2175956}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 2.120286, 'lng': 33.2175956}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 2.120286, 'lng': 33.2175956}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 2.120286, 'lng': 33.2175956}, 'html_instructions': 'Head', 'polyline': {'points': 'yb}K_yviE'}, 'start_location': {'lat': 2.120286, 'lng': 33.2175956}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'yb}K_yviE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 94.1m
#
# Found road within first radius (25m), stopping search

# %%
#now for aisa (in batches to check API cost)

# %%
results_aisa = process_all_clusters(aisa_sampled_clusters_gdf)
# Out:
# Starting to process 70 clusters...
#
# Processing 1/70: grid_id 24524
#
# Original centroid (lat, lon): 1.324168487839603, 33.919441817218136
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Processing 2/70: grid_id 23364
#
# Original centroid (lat, lon): 1.5955782704067638, 33.856628220640616
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.5959976, 'lng': 33.8584445}, 'southwest': {'lat': 1.5953112, 'lng': 33.8573198}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '0.3 km', 'value': 307}, 'duration': {'text': '1 min', 'value': 88}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.5953166, 'lng': 33.8573198}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.5959976, 'lng': 33.8573305}, 'steps': [{'distance': {'text': '71 m', 'value': 71}, 'duration': {'text': '1 min', 'value': 7}, 'end_location': {'lat': 1.595938, 'lng': 33.8579436}, 'html_instructions': 'Head <b>east</b>', 'polyline': {'points': '_vvHiwsmEDECgBHK'}, 'start_location': {'lat': 1.5959976, 'lng': 33.8573305}, 'travel_mode': 'DRIVING'}, {'distance': {'text': '56 m', 'value': 56}, 'duration': {'text': '1 min', 'value': 19}, 'end_location': {'lat': 1.595978, 'lng': 33.8584445}, 'html_instructions': 'Slight <b>left</b>', 'maneuver': 'turn-slight-left', 'polyline': {'points': 'suvHc{smEAc@C]Aa@'}, 'start_location': {'lat': 1.595938, 'lng': 33.8579436}, 'travel_mode': 'DRIVING'}, {'distance': {'text': '28 m', 'value': 28}, 'duration': {'text': '1 min', 'value': 18}, 'end_location': {'lat': 1.5957422, 'lng': 33.8583977}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': '{uvHg~smERFHBPC'}, 'start_location': {'lat': 1.595978, 'lng': 33.8584445}, 'travel_mode': 'DRIVING'}, {'distance': {'text': '27 m', 'value': 27}, 'duration': {'text': '1 min', 'value': 12}, 'end_location': {'lat': 1.5955016, 'lng': 33.8583866}, 'html_instructions': 'Slight <b>right</b>', 'maneuver': 'turn-slight-right', 'polyline': {'points': 'ktvH_~smEH@d@?'}, 'start_location': {'lat': 1.5957422, 'lng': 33.8583977}, 'travel_mode': 'DRIVING'}, {'distance': {'text': '24 m', 'value': 24}, 'duration': {'text': '1 min', 'value': 12}, 'end_location': {'lat': 1.5953706, 'lng': 33.8582163}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points

# Trying direction search 4/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.3623629, 'lng': 33.7187406}, 'southwest': {'lat': 1.3623629, 'lng': 33.7187406}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.3623629, 'lng': 33.7187406}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.3623629, 'lng': 33.7187406}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 1.3623629, 'lng': 33.7187406}, 'html_instructions': 'Head', 'polyline': {'points': 'waiGcuxlE'}, 'start_location': {'lat': 1.3623629, 'lng': 33.7187406}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'waiGcuxlE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 394.3m
#
# Found road within first radius (25m), stopping search
#
# Processing 7/70: grid_id 21459
#
# Original centroid (lat, lon): 1.2789912125206329, 33.75764143866058
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.2766079, 'lng': 33.7593007}, 'southwest': {'lat': 1.2766079, 'lng': 33.7593007}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'html_instructions': 'Head', 'polyline': {'points': 'yixFsr`mE'}, 'start_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'yixFsr`mE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 321.8m
# Trying direction search 2/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.2766079, 'lng': 33.7593007}, 'southwest': {'lat': 1.2766079, 'lng': 33.7593007}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'html_instructions': 'Head', 'polyline': {'points': 'yixFsr`mE'}, 'start_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'yixFsr`mE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 321.8m
# Trying direction search 3/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.2766079, 'lng': 33.7593007}, 'southwest': {'lat': 1.2766079, 'lng': 33.7593007}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'html_instructions': 'Head', 'polyline': {'points': 'yixFsr`mE'}, 'start_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'yixFsr`mE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 321.8m
# Trying direction search 4/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.2766079, 'lng': 33.7593007}, 'southwest': {'lat': 1.2766079, 'lng': 33.7593007}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'html_instructions': 'Head', 'polyline': {'points': 'yixFsr`mE'}, 'start_location': {'lat': 1.2766079, 'lng': 33.7593007}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'yixFsr`mE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 321.8m
#
# Found road within first radius (25m), stopping search
#
# Processing 8/70: grid_id 25562
#
# Original centroid (lat, lon): 1.4869747701932174, 33.97343662751976
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.4872388, 'lng': 33.9734089}, 'southwest': {'lat': 1.4869841, 'lng': 33.9732136}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '40 m', 'value': 40}, 'duration': {'text': '1 min', 'value': 14}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.4869841, 'lng': 33.9732335}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.4872388, 'lng': 33.9734089}, 'steps': [{'distance': {'text': '27 m', 'value': 27}, 'duration': {'text': '1 min', 'value': 4}, 'end_location': {'lat': 1.4870993, 'lng': 33.9732136}, 'html_instructions': 'Head <b>southwest</b>', 'polyline': {'points': 'gnaHyljnEZf@'}, 'start_location': {'lat': 1.4872388, 'lng': 33.9734089}, 'travel_mode': 'DRIVING'}, {'distance': {'text': '13 m', 'value': 13}, 'duration': {'text': '1 min', 'value': 10}, 'end_location': {'lat': 1.4869841, 'lng': 33.9732335}, 'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Destination will be on the left</div>', 'maneuver': 'turn-left', 'polyline': {'points': 'kmaHqkjnEDAHCF@'}, 'start_location': {'lat': 1.4870993, 'lng': 33.9732136}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'gnaHyljnEZf@DAPA'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 28.4m
# Trying direction search 2/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.4872692, 'lng': 33.9734516}, 'southwest': {'lat': 1.4869841, 'lng': 33.9732136}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '46 m', 'value': 46}, 'duration': {'text': '1 min', 'value': 14}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.4869841, 'lng': 33.9732335}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.4872692, 'lng': 33.9734516}, 'steps': [{'distance': {'text': '33 m', 'value': 33}, 'duration': {'text': '1 min', 'value': 4}, 'end_location': {'lat': 1.4870993, 'lng': 33.9732136}, 'html_instructions': 'Head <b>southwest</b>', 'polyline': {'points': 'mnaHamjnE`@n@'}, 'start_location': {'lat': 1.4872692, 'lng': 33.9734516}, 'travel_mode': 'DRIVING'}, {'distance': {'text': '13 m', 'value': 13}, 'duration': {'text': '1 min', 'value': 10}, 'end_location': {'lat': 1.4869841, 'lng': 33.9732335}, 'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Destination will be on the left</div>', 'maneuver': 'turn-left', 'polyline': {'points': 'kmaHqkjnEDAHCF@'}, 'start_location': {'lat': 1.4870993, 'lng': 33.9732136}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'mnaHamjnE`@n@DAPA'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 28.4m
# Trying direction search 3/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.4869841, 'lng': 33.9732335}, 'southwest': {'lat': 1.4868234, 'lng': 33.9731978}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '18 m', 'value': 18}, 'duration': {'text': '1 min', 'value': 2}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.4869841, 'lng': 33.9732335}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.4868234, 'lng': 33.9731978}, 'steps': [{'distance': {'text': '18 m', 'value': 18}, 'duration': {'text': '1 min', 'value': 2}, 'end_location': {'lat': 1

# Trying direction search 4/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.2981136, 'lng': 33.6763436}, 'southwest': {'lat': 1.2981136, 'lng': 33.6763436}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.2981136, 'lng': 33.6763436}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.2981136, 'lng': 33.6763436}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 1.2981136, 'lng': 33.6763436}, 'html_instructions': 'Head', 'polyline': {'points': 'ep|FclplE'}, 'start_location': {'lat': 1.2981136, 'lng': 33.6763436}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'ep|FclplE'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 120.2m
#
# Found road within first radius (25m), stopping search
#
# Processing 68/70: grid_id 19450
#
# Original centroid (lat, lon): 1.5594678070538066, 33.64986025996255
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.5601566, 'lng': 33.6491376}, 'southwest': {'lat': 1.559997, 'lng': 33.6490352}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '21 m', 'value': 21}, 'duration': {'text': '1 min', 'value': 2}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.559997, 'lng': 33.6490352}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.5601566, 'lng': 33.6491376}, 'steps': [{'distance': {'text': '21 m', 'value': 21}, 'duration': {'text': '1 min', 'value': 2}, 'end_location': {'lat': 1.559997, 'lng': 33.6490352}, 'html_instructions': 'Head <b>southwest</b>', 'polyline': {'points': '_voHcbklE^R'}, 'start_location': {'lat': 1.5601566, 'lng': 33.6491376}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': '_voHcbklE^R'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 110.8m
# Trying direction search 2/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.5608864, 'lng': 33.6511007}, 'southwest': {'lat': 1.5599109, 'lng': 33.6490352}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '0.4 km', 'value': 372}, 'duration': {'text': '1 min', 'value': 59}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.559997, 'lng': 33.6490352}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.5599109, 'lng': 33.6511007}, 'steps': [{'distance': {'text': '0.3 km', 'value': 277}, 'duration': {'text': '1 min', 'value': 40}, 'end_location': {'lat': 1.5607629, 'lng': 33.6492827}, 'html_instructions': 'Head <b>northwest</b>', 'polyline': {'points': 'mtoHknklEoA`@SH_B`@?B@V?FBL@RDX?\\Fp@BlB'}, 'start_location': {'lat': 1.5599109, 'lng': 33.6511007}, 'travel_mode': 'DRIVING'}, {'distance': {'text': '0.1 km', 'value': 95}, 'duration': {'text': '1 min', 'value': 19}, 'end_location': {'lat': 1.559997, 'lng': 33.6490352}, 'html_instructions': 'Turn <b>left</b>', 'maneuver': 'turn-left', 'polyline': {'points': 'wyoH_cklE~@GvAv@'}, 'start_location': {'lat': 1.5607629, 'lng': 33.6492827}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'mtoHknklEcBj@_B`@?B@^D`@Dv@J~C~@GvAv@'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 157.0m
# Trying direction search 3/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.559997, 'lng': 33.6490352}, 'southwest': {'lat': 1.5598727, 'lng': 33.6489554}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '16 m', 'value': 16}, 'duration': {'text': '1 min', 'value': 2}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.559997, 'lng': 33.6490352}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.5598727, 'lng': 33.6489554}, 'steps': [{'distance': {'text': '16 m', 'value': 16}, 'duration': {'text': '1 min', 'value': 2}, 'end_location': {'lat': 1.559997, 'lng': 33.6490352}, 'html_instructions': 'Head <b>northeast</b>', 'polyline': {'points': 'etoH_aklEEASM'}, 'start_location': {'lat': 1.5598727, 'lng': 33.6489554}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'etoH_aklEYO'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 110.2m
# Trying direction search 4/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.559997, 'lng': 33.6490352}, 'southwest': {'lat': 1.559894, 'lng': 33.6489691}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '14 m', 'value': 14}, 'duration': {'text': '1 min', 'value': 2}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.559997, 'lng': 33.6490352}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.559894, 'lng': 33.6489691}, 'steps': [{'distance': {'text': '14 m', 'value': 14}, 'duration': {'text': '1 min', 'value': 2}, 'end_location': {'lat': 1.559997, 'lng': 33.6490352}, 'html_instructions': 'Head <b>northeast</b>', 'polyline': {'points': 'itoHaaklEA?SM'}, 'start_location': {'lat': 1.559894, 'lng': 33.6489691}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'itoHaaklEUM'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 109.8m
#
# Found road within first radius (25m), stopping search
#
# Processing 69/70: grid_id 20952
#
# Original centroid (lat, lon): 1.3061386612615706, 33.730684570034356
#
# Searching at 25 meters radius...
# Trying direction search 1/4 at 25m radius
# [{'bounds': {'northeast': {'lat': 1.3075618, 'lng': 33.729593}, 'southwest': {'lat': 1.3075618, 'lng': 33.729593}}, 'copyrights': 'Map data ©2024', 'legs': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_address': 'Unnamed Road, Uganda', 'end_location': {'lat': 1.3075618, 'lng': 33.729593}, 'start_address': 'Unnamed Road, Uganda', 'start_location': {'lat': 1.3075618, 'lng': 33.729593}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 1
, 'html_instructions': 'Head <b>northeast</b>', 'polyline': {'points': 'cztHalcnEQG'}, 'start_location': {'lat': 1.586425, 'lng': 33.9374486}, 'travel_mode': 'DRIVING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'cztHalcnEQG'}, 'summary': '', 'warnings': [], 'waypoint_order': []}]
# Found road point at distance: 11.7m
#
# Found road within first radius (25m), stopping search

# %%
#check results 
print(results_dwanwana_dokolo.head())
print(results_aisa)
# Out:
#    grid_id station_name  buffer_km  est_population_2020  centroid_lat  \
# 0     8263  Dwanwana FM       25.0           179.262650      1.858127
# 1     9989  Dwanwana FM       25.0           381.704590      2.093348
# 2    13719  Dwanwana FM       25.0           341.559753      2.002846
# 3    12682  Dwanwana FM       25.0           324.227936      1.849056
# 4     9098  Dwanwana FM       25.0           290.368835      1.722416
#
#    centroid_lon                                 centroid_maps_link  \
# 0     33.056539  https://www.google.com/maps?q=1.85812651614902...
# 1     33.146474  https://www.google.com/maps?q=2.09334789077011...
# 2     33.344293  https://www.google.com/maps?q=2.00284642067057...
# 3     33.290314  https://www.google.com/maps?q=1.84905632797708...
# 4     33.101489  https://www.google.com/maps?q=1.72241633301866...
#
#   cluster_type  nearest_road_lat  nearest_road_lon  distance_to_road  \
# 0  replacement          1.858005         33.056349         25.063619
# 1  replacement          2.094389         33.147156        137.861247
# 2  replacement          2.005120         33.343419        269.533294
# 3  replacement          1.849347         33.289630         82.581111
# 4         main          1.722582         33.101458         18.653578
#
#                               nearest_road_maps_link  found_at_radius  \
# 0  https://www.google.com/maps?q=1.858005,33.0563492               25
# 1  https://www.google.com/maps?q=2.0943889,33.147...               25
# 2  https://www.google.com/maps?q=2.0051201,33.343...               25
# 3  https://www.google.com/maps?q=1.8493468,33.289...               25
# 4  https://www.google.com/maps?q=1.7225822,33.101...               25
#
#    processing_success                                 geometry_grid_cell
# 0                True  POLYGON ((33.06103492495046 1.853602761066021,...
# 1                True  POLYGON ((33.15097015834338 2.088823883597678,...
# 2                True  POLYGON ((33.34878766894459 1.9983219495517408...
# 3                True  POLYGON ((33.294809077609216 1.844532035315588...
# 4                True  POLYGON ((33.1059842060682 1.7178924806024494,...
#     grid_id station_name  buffer_km  est_population_2020  centroid_lat  \
# 0     24524      Aisa FM       25.0           425.846130      1.324168
# 1     23364      Aisa FM       25.0           661.170654      1.595578
# 2     18590      Aisa FM       25.0           517.236816      1.469014
# 3     22674      Aisa FM       25.0           730.694519      1.505130
# 4     20788      Aisa FM       25.0            92.748978      1.360421
# ..      ...          ...        ...                  ...           ...
# 65    25898      Aisa FM       25.0           545.688416      1.450783
# 66    19931      Aisa FM       25.0           536.633240      1.297107
# 67    19450      Aisa FM       25.0           768.279663      1.559468
# 68    20952      Aisa FM       25.0           892.214722      1.306139
# 69    24893      Aisa FM       25.0           400.593506      1.586497
#
#     centroid_lon                                 centroid_maps_link  \
# 0      33.919442  https://www.google.com/maps?q=1.32416848783960...
# 1      33.856628  https://www.google.com/maps?q=1.59557827040676...
# 2      33.604888  https://www.google.com/maps?q=1.46901386082312...
# 3      33.820636  https://www.google.com/maps?q=1.50512989025721...
# 4      33.721712  https://www.google.com/maps?q=1.36042052665992...
# ..           ...                                                ...
# 65     33.991398  https://www.google.com/maps?q=1.45078315744206...
# 66     33.676752  https://www.google.com/maps?q=1.29710722710182...
# 67     33.649860  https://www.google.com/maps?q=1.55946780705380...
# 68     33.730685  https://www.google.com/maps?q=1.30613866126157...
# 69     33.937526  https://www.google.com/maps?q=1.58649674968015...
#
#    cluster_type  nearest_road_lat  nearest_road_lon  distance_to_road  \
# 0   replacement               NaN               NaN               NaN
# 1   replacement          1.595317         33.857320         82.216246
# 2   replacement          1.469210         33.604877         21.668160
# 3   replacement          1.505491         33.821431         97.028562
# 4          main          1.362363         33.718741        394.313015
# ..          ...               ...               ...               ...
# 65  replacement          1.450433         33.991290         40.509159
# 66         main          1.298114         33.676344        120.197512
# 67  replacement          1.559894         33.648969        109.795163
# 68         main          1.307562         33.729593        198.798922
# 69         main          1.586602         33.937535         11.688961
#
#                                nearest_road_maps_link  found_at_radius  \
# 0                                                None              NaN
# 1   https://www.google.com/maps?q=1.5953166,33.857...             25.0
# 2   https://www.google.com/maps?q=1.4692095,33.604...             25.0
# 3   https://www.google.com/maps?q=1.5054912,33.821431             25.0
# 4   https://www.google.com/maps?q=1.3623629,33.718...             25.0
# ..                                                ...              ...
# 65  https://www.google.com/maps?q=1.450433,33.9912905             25.0
# 66  https://www.google.com/maps?q=1.2981136,33.676...             25.0
# 67  https://www.google.com/maps?q=1.559894,33.6489691             25.0
# 68  https://www.google.com/maps?q=1.3075618,33.729593             25.0
# 69  https://www.google.com/maps?q=1.5866021,33.937...             25.0
#
#     processing_success                                 geometry_grid_cell
# 0                False  POLYGON ((33.92393412771333 1.3196437671616883...
# 1                 True  POLYGON ((33.861120940584726 1.591053276691258...
# 2                 True  POLYGON ((33.60938098343718 1.4644892640730185...
# 3                 True  POLYGON ((33.82512917378177 1.5006050321086095...
# 4                 True  POLYGON ((33.7262049588844 1.3558959056253197,...
# ..                 ...                                                ...
# 65                True  POLYGON ((33.995889678764186 1.446258232999840...
# 66                True  POLYGON ((33.68124484439569 1.292582703274217,...
# 67                True  POLYGON ((33.65435360069276 1.5549430813347738...
# 68                True  POLYGON ((33.73517742283334 1.30161408525251, ...
# 69                True  POLYGON ((33.94201847047474 1.5819716906628953...
#
# [70 rows x 15 columns]

# %%
print(results_aisa.processing_success.value_counts())
#only one missing (which is a replacement cluster, lets just give the centroid)

print(results_dwanwana_dokolo.processing_success.value_counts())

#save. 
results_aisa.to_csv(TEMP_DATA_DIR / 'aisa_roadpoints.csv')      
results_dwanwana_dokolo.to_csv(TEMP_DATA_DIR / 'dwanwana_dokolo_roadpoints.csv')      
      
#pull location characteristics, what is the district, village, county, for each point.
# Out:
# processing_success
# True     69
# False     1
# Name: count, dtype: int64
# processing_success
# True    140
# Name: count, dtype: int64

# %%
def create_enumeration_area_map(row):
    """
    Create a map for a single enumeration area showing:
    1. The nearest road point
    2. The grid cell geometry
    3. The centroid
    
    Parameters:
    row: A single row from the results DataFrame
    """
    import folium
    from shapely import wkt
    
    # Convert WKT string back to geometry
    grid_geometry = wkt.loads(row.geometry)
    
    # Create a map centered on the nearest road point (if it exists) or centroid
    if row.nearest_road_lat and row.nearest_road_lon:
        center_lat, center_lon = row.nearest_road_lat, row.nearest_road_lon
    else:
        center_lat, center_lon = row.centroid_lat, row.centroid_lon
        
    m = folium.Map(
        location=[center_lat, center_lon],
        zoom_start=17,
        tiles='https://mt1.google.com/vt/lyrs=m&x={x}&y={y}&z={z}',
        attr='Google Maps'
    )
    
    # Add the grid cell geometry
    folium.GeoJson(
        grid_geometry.__geo_interface__,
        style_function=lambda x: {
            'fillColor': '#ffaf00',
            'color': '#ff0000',
            'weight': 2,
            'fillOpacity': 0.1
        },
        popup=f"Grid ID: {row.grid_id}"
    ).add_to(m)
    
    # Add the centroid point
    folium.CircleMarker(
        location=[row.centroid_lat, row.centroid_lon],
        radius=6,
        color='blue',
        fill=True,
        popup='Centroid'
    ).add_to(m)
    
    # Add the nearest road point if it exists
    if row.nearest_road_lat and row.nearest_road_lon:
        folium.CircleMarker(
            location=[row.nearest_road_lat, row.nearest_road_lon],
            radius=6,
            color='red',
            fill=True,
            popup=f'Nearest Road Point (Distance: {row.distance_to_road:.1f}m)'
        ).add_to(m)
        
        # Add a line connecting centroid to nearest road point
        folium.PolyLine(
            locations=[
                [row.centroid_lat, row.centroid_lon],
                [row.nearest_road_lat, row.nearest_road_lon]
            ],
            weight=2,
            color='red',
            opacity=0.8
        ).add_to(m)
    
    # Add a legend
    legend_html = '''
    <div style="position: fixed; bottom: 50px; left: 50px; z-index: 1000; 
         background-color: white; padding: 10px; border: 2px solid grey; border-radius: 5px;">
        <p><i style="background: red; width: 10px; height: 10px; display: inline-block; border-radius: 50%;"></i> Nearest Road</p>
        <p><i style="background: blue; width: 10px; height: 10px; display: inline-block; border-radius: 50%;"></i> Centroid</p>
        <p><i style="border: 2px solid red; width: 10px; height: 10px; display: inline-block;"></i> Grid Boundary</p>
    </div>
    '''
    m.get_root().html.add_child(folium.Element(legend_html))
    
    return m

# Create maps for all enumeration areas
for idx, row in results_df.iterrows():
    m = create_enumeration_area_map(row)
    m.save(f'enumeration_area_map_{row.grid_id}.html')

# Or test with just one area
test_map = create_enumeration_area_map(results_df.iloc[0])
test_map.save('test_enumeration_area_map.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18632\3502675820.py in ?()
#      83     return m
#      84
#      85 # Create maps for all enumeration areas
#      86 for idx, row in results_df.iterrows():
# ---> 87     m = create_enumeration_area_map(row)
#      88     m.save(f'enumeration_area_map_{row.grid_id}.html')
#      89
#      90 # Or test with just one area
#
# ~\AppData\Local\Temp\ipykernel_18632\3502675820.py in ?(row)
#      11     import folium
#      12     from shapely import wkt
#      13
#      14     # Convert WKT string back to geometry
# ---> 15     grid_geometry = wkt.loads(row.geometry)
#      16
#      17     # Create a map centered on the nearest road point (if it exists) or centroid
#      18     if row.nearest_road_lat and row.nearest_road_lon:
#
# c:\Users\linss\micromamba\envs\geoenv\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'geometry'
